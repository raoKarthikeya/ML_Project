# %%
SEARCH_TERM = "Trump"
TWEETS_COUNT = 300
TIME_LIMIT = 120



import keys
import os
from credentials import *
import pandas as pd
import numpy as np
import tweepy
from tweepy import OAuthHandler
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline

dir_path = os.getcwd()
dir_path_data = dir_path + "/Data/"


consumer_key = keys.consumer_key
consumer_secret = keys.consumer_secret
access_token = keys.access_token
access_secret = keys.access_secret


# print(consumer_key)
# print(consumer_secret)
# print(access_token)
# print(access_secret)


print(dir_path)
print(dir_path_data)

 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)
# Out:
# C:\sjsu-git\ML_Project
# C:\sjsu-git\ML_Project/Data/

# %%
# Before running this code
# make a directory named Data and provide the path of the directory at INPUT_DATAPATH
# set SEARCH_TERM as what you would like to search from twitter "ex: apple"
# which would produce the list of tweets for the term "apple" 
# and also store the twitter data into the file stream_apple.json in the directory of INPUT_DATAPATH


from tweepy import Stream
from tweepy.streaming import StreamListener
import time
import string
import json
import time
import os


class MyListener(StreamListener):
    """Custom StreamListener for streaming data."""

    def __init__(self, data_dir, query, time_limit):
        query_fname = ''.join(convert_valid(one_char) for one_char in query)
        self.start_time = time.time()
        self.limit = TIME_LIMIT
        self.outfile = "%s/stream_%s.json" % (data_dir, query_fname)
        
    def on_data(self, data):
        # removes if a file already exists with same name and creates new file and writes into that
        
        if os.path.exists(self.outfile):
            if os.path.getsize(self.outfile) > 2**20 * 2**10: # 1MB
                os.remove(self.outfile)
        with open(self.outfile,'a') as f:
            try:
                f.writelines(data.strip("\n"))

                if (time.time() - self.start_time) > self.limit:
                    print('WRITE COMPLETE')
                    time.sleep(1)
                    f.close()
                    return False
                return True

            except BaseException as e:
                print("Error on_data: %s" % str(e))
                time.sleep(5)


    def on_error(self, status):
        print(status)
        return True

    
def convert_valid(one_char):
    """Convert a character into '_' if invalid.
    Arguments:
        one_char -- the char to convert
    Return:
        Character -- converted char
    """
    valid_chars = "-_.%s%s" % (string.ascii_letters, string.digits)
    if one_char in valid_chars:
        return one_char
    else:
        return '_'

# %%
twitter_stream = Stream(auth, MyListener(dir_path_data, SEARCH_TERM, TIME_LIMIT)) #calling stream function to stream in live data
twitter_stream.filter(track=[SEARCH_TERM]) # filters data based on search term on storing
# Out:
# WRITE COMPLETE

# %%
from nltk.tokenize import word_tokenize, TweetTokenizer
import re
import operator 
import json
from collections import Counter
from nltk.corpus import stopwords
import string
from nltk import bigrams 
from collections import defaultdict
import nltk

com = defaultdict(lambda : defaultdict(int))
    
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via', 'RT', ':', ',', '’',
                                                   'i\'m', '…', '...', 'a', 'b', 'c'
                                                  'd','g','j','m','p','s','v','y',
                                                  'e','h','k','n','q','t','w','z',
                                                  'f','i','l','o','r','u','x', 'http', 'https',
                                                  'ó','ल','ु','்','ज','I','ब','य','द','ै','ट',
                                                   'भ','ग','प','व','ி','श','amp',
                                                   'ू','।','ध','ு','च','1','ा',]    

      

tknzr = TweetTokenizer()
num_of_tweets = 0
tweets = []
original_tweets = []
terms = ''
fname = dir_path_data +'/stream_'+SEARCH_TERM+'.json'
with open(fname, 'r') as f:
    count_all = Counter()
    
    for line in f:
        num_of_tweets += 1
        tweet = json.loads(line)
        # Create a list with all the terms
        original = ''
        if 'extended_tweet' in tweet:
            terms = [term.replace('#', '') for term in tknzr.tokenize(tweet['extended_tweet']['full_text']) if term.lower() not in stop 
                                                                    and 'http' not in term
                                                                    and not term.startswith('@')]
            original = tweet.get('extended_tweet').get('full_text')
            
        elif 'retweeted_status' in tweet:
            try:
                terms = [term.replace('#', '') for term in tknzr.tokenize(tweet['retweeted_status']['extended_tweet']['full_text']) if term.lower() not in stop 
                                                                    and 'http' not in term
                                                                    and not term.startswith('@')]
                original = tweet.get('retweeted_status').get('extended_tweet').get('full_text')
            except:
                pass
        else:
            try:
                terms = [term.replace('#', '') for term in tknzr.tokenize(tweet['text']) if term.lower() not in stop 
                                                                    and 'http' not in term
                                                                    and not term.startswith('@')]
                original = tweet['text']
            except:
                pass
        
#         print(original)
        tweets.append(terms)
        original_tweets.append(original)
        terms_bigram = list(nltk.bigrams(terms))
        
#         print(terms)
#         print(terms_bigram)

        # Build co-occurrence matrix
        for i in range(len(terms)-1):            
            for j in range(i+1, len(terms)):
                w1, w2 = sorted([terms[i], terms[j]])                
                if w1 != w2:
                    com[w1][w2] += 1
    
        # Update the counter
        count_all.update(terms_bigram)
        
# Print the first 5 most frequent words
# print(count_all.most_common(10))


original_tweets = list(filter(None, original_tweets))
# every single tweet vocab put into a list
flat_list = [term for tweet in tweets for term in tweet ]
hashtags_list = [hasht for hasht in flat_list if hasht.startswith('#')]

all_terms_dist = nltk.FreqDist(flat_list)
hash_terms_dist = nltk.FreqDist(hashtags_list)


print(all_terms_dist.most_common(10))

# print(count_all.most_common())


com_max = []
# For each term, look for the most common co-occurrent terms
for t1 in com:
    t1_max_terms = sorted(com[t1].items(), key=operator.itemgetter(1), reverse=True)[:5]
    for t2, t2_count in t1_max_terms:
        com_max.append(((t1, t2), t2_count))
# Get the most frequent co-occurrences
terms_max = sorted(com_max, key=operator.itemgetter(1), reverse=True)
print(terms_max[:10])

print(num_of_tweets)


'''
Bigrams
A collocation is a sequence of words that occur together unusually often. 
Thus red wine is a collocation, whereas the wine is not. 
A characteristic of collocations is that they are resistant to substitution
with words that have similar senses; for example, maroon wine sounds definitely odd.
'''

''''''
# Out:
# [('Trump', 6152), ('”', 783), ('President', 762), ('“', 758), ('Obama', 627), ('Donald', 570), ('like', 551), ('get', 500), ('people', 440), ('Cohen', 432)]
# [(('🇸', '🇺'), 2000), (('“', '”'), 1089), (('Trump', '“'), 892), (('Trump', '”'), 886), (('「', '」'), 824), (('Obama', 'Trump'), 796), (('President', 'Trump'), 737), (('Donald', 'Trump'), 709), (('Trump', 'like'), 605), (('Cohen', 'Trump'), 519)]
# 7104
# ''

# %%
import math
from nltk.corpus import opinion_lexicon


# n_docs is the total n. of tweets
p_t = {}
p_t_com = defaultdict(lambda : defaultdict(int))
 
for term, n in all_terms_dist.most_common():
    p_t[term] = n / num_of_tweets
    for t2 in com[term]:
        p_t_com[term][t2] = com[term][t2] / num_of_tweets
        

positive_lex = opinion_lexicon.positive()[:]   
negative_lex = opinion_lexicon.negative()[:]
positive_vocab = [
    'good', 'nice', 'great', 'awesome', 'outstanding',
    'fantastic', 'terrific', ':)', ':-)', 'like', 'love',
    # shall we also include game-specific terms?
    # 'triumph', 'triumphal', 'triumphant', 'victory', etc.
]
positive_vocab += positive_lex
negative_vocab = [
    'bad', 'terrible', 'crap', 'useless', 'hate', ':(', ':-(',
    # 'defeat', etc.
]
negative_vocab += negative_lex

pmi = defaultdict(lambda : defaultdict(int))
for t1 in p_t:
    for t2 in com[t1]:
        denom = p_t[t1] * p_t[t2]
        pmi[t1][t2] = math.log2(p_t_com[t1][t2] / denom)
 
semantic_orientation = {}
for term, n in p_t.items():
    positive_assoc = sum(pmi[term][tx] for tx in positive_vocab)
    negative_assoc = sum(pmi[term][tx] for tx in negative_vocab)
    semantic_orientation[term] = positive_assoc - negative_assoc

semantic_sorted = sorted(semantic_orientation.items(), 
                         key=operator.itemgetter(1), 
                         reverse=True)
top_pos = semantic_sorted[:10]
top_neg = semantic_sorted[-10:]
 
print(top_pos)
print(top_neg)

# print(semantic_sorted)
# Out:
# [('Kanye', 76.3071985604208), ('beautiful', 67.58974510157519), ('Un', 65.80459938408549), ('Embassy', 62.89615603707144), ('amounts', 57.13263475598647), ('accomplishment', 56.55877749758869), ('Congratulations', 54.39095889732376), ('endorse', 53.51338562049192), ('Best', 51.06727037102351), ('incredible', 50.302786339093295)]
# [('even', -170.66727525821233), ('White', -171.45446550246493), ('..', -178.5562216506361), ('Donald', -180.429368551364), ('Obama', -186.12568340475295), ('administration', -191.55992138072457), ('Mueller', -209.27422002138576), ('GOP', -235.36289743744274), ('John', -253.59052147976723), ('McCain', -326.4003260459149)]

# %%
from wordcloud import WordCloud
import random

def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    wordcloud = WordCloud(background_color=color,
                      width=2500,
                      height=2000,
                      max_words=100
                     ).generate(words)
#     wordcloud.recolor(color_func = grey_color_func(word = words))
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

pos_term = [terms[0] for terms in semantic_sorted if terms[1] > 0 
            and not terms[0].startswith('@')]

neg_term = [terms[0] for terms in semantic_sorted if terms[1] < 0 
            and not terms[0].startswith('@')]

neutral_term = [terms[0] for terms in semantic_sorted if terms[1] == 0 
            and not terms[0].startswith('@')]

wordcloud_draw(pos_term, 'white')
wordcloud_draw(neg_term)

# %%
count = 0
target = []
for tweet in original_tweets:
    score = 0
    pos_counter = 0
    neg_counter = 0
    for word in semantic_sorted:
        if word[0].lower() in tweet.lower() and not word[0].isdigit() and len(word[0]) >= 3:
#             print(word)
            if word[1] > 0:
                pos_counter += 1
            if word[1] < 0:
                neg_counter += 1
        
            score += word[1]
    if(pos_counter > neg_counter or score > 0):
        count += 1
        sentiment = 'Positive'
    else:
        sentiment = 'Negative'
    target.append(sentiment)

# %%
print(count)
print(len(original_tweets))
print(len(target))
# Out:
# 31
# 5485
# 5485

# %%
# We create a pandas dataframe as follows:
pd.set_option('display.max_colwidth', -1) # Setting this so we can see the full content of cells
df = pd.DataFrame(data=[tweet for tweet in original_tweets], columns=['text'])
df['sentiment']  = np.array([sentiment for sentiment in target])

# %%
import re
from textblob import TextBlob


def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analyze_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
#     print(clean_tweet(tweet))
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 'Positive'
#     elif ( analysis.sentiment.polarity == 0):
#         return 'Neutral'
    else:
        return 'Negative'

def analyze_subject(tweet):
    '''
    Utility function to classify the subjectivity of a tweet
    using textblob.
    '''
#     print(clean_tweet(tweet))
    analysis = TextBlob(clean_tweet(tweet))
    return analysis.sentiment.subjectivity
#     if analysis.sentiment.subjectivity > 0.5:
#         return 'Subjective'
#     else:
#         return 'Not Subjective'



# We create a column with the result of the analysis:
df['SA'] = np.array([ analyze_sentiment(tweet) for tweet in df['text'] ])
df['Subjective'] = np.array([ analyze_subject(tweet) for tweet in df['text'] ])

# We display the updated dataframe with the new column:
display(df[['text', 'SA', 'Subjective']].head())

pos_tweets = [ tweet for index, tweet in enumerate(df['text']) if df['SA'][index] == 'Positive']
neg_tweets = [ tweet for index, tweet in enumerate(df['text']) if df['SA'][index] == 'Negative']
# neu_tweets = [ tweet for index, tweet in enumerate(df['text']) if df['SA'][index] == 'Neutral']


print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(df['text'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(df['text'])))
# print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(df['text'])))
# Out:
#                                                                                                                                                                                                                                                                                   text  \
# 0  New #Deconstructed podcast: Did Donald Trump just take us one step closer to war with Iran? Featuring @TVietor08 and @mehdirhasan\nhttps://t.co/pgPGxwsWt3
# 1  @MalcolmNance Oh there will be things named after Trump...prisons. #LastWord
# 2  Iran's supreme leader trolls Trump with photo of himself reading "Fire and Fury" days after Trump ends nuclear deal https://t.co/Rmv3IZq0hU https://t.co/7pk8vHzgrP
# 3  LOL the damn truth hurts....\nPresident Donald Trump Attacks Stop After Michael Avenatti Revelation | ... https://t.co/HgRoaqVNyw via @YouTube
# 4  🔴EXTORTION PLOT: Women Sexually Assaulted by Schneiderman Turned to Trump &amp; Cohen in 2013; Then Schneiderman Targeted Trump\n\nNY AG Schneiderman wanted to unseat President Trump from the White House to keep his sexual assault of women a secret.\n https://t.co/SmF1LHW1as
#
#          SA  Subjective
# 0  Positive  0.454545
# 1  Negative  0.000000
# 2  Negative  0.000000
# 3  Positive  0.700000
# 4  Positive  0.591667
# Percentage of positive tweets: 43.68277119416591%
# Percentage de negative tweets: 56.31722880583409%

# %%
df.head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                          text  \
# 0   New #Deconstructed podcast: Did Donald Trump just take us one step closer to war with Iran? Featuring @TVietor08 and @mehdirhasan\nhttps://t.co/pgPGxwsWt3
# 1   @MalcolmNance Oh there will be things named after Trump...prisons. #LastWord
# 2   Iran's supreme leader trolls Trump with photo of himself reading "Fire and Fury" days after Trump ends nuclear deal https://t.co/Rmv3IZq0hU https://t.co/7pk8vHzgrP
# 3   LOL the damn truth hurts....\nPresident Donald Trump Attacks Stop After Michael Avenatti Revelation | ... https://t.co/HgRoaqVNyw via @YouTube
# 4   🔴EXTORTION PLOT: Women Sexually Assaulted by Schneiderman Turned to Trump &amp; Cohen in 2013; Then Schneiderman Targeted Trump\n\nNY AG Schneiderman wanted to unseat President Trump from the White House to keep his sexual assault of women a secret.\n https://t.co/SmF1LHW1as
# 5   @Robbin_Young @StormyDaniels @MichaelAvenatti This is about Trump being gutter trash, not them, you’ve got it backwards... https://t.co/RwAsMurqD2
# 6   This lawyer claims he told Trump and Cohen about sexual misconduct by Schneiderman back in 2013 because he believed the DA would not prosecute.\n\nIt’s very hard to believe an attorney would learn of a sexual misconduct and turn to Donald Trump for help instead of law enforcement. https://t.co/rzjSAheEk4
# 7   If you ever wonder what kind of knee-jerk stupidity we're up against, just remember 41% of Trump supporters polled said they were in favor of bombing Agrabah.\n\nThat's the fictional country from Aladdin. https://t.co/QugIhvQZu6
# 8   Donald Trump says he's embarrassed when world leaders come to visit him, because the first thing they ask about is the investigation into his criminal scandals. He's going to be really embarrassed when people come to visit him in prison.
# 9   When American hostage Otto Warmbier was returned from North Korea — he was blind, deaf, and died days later.\n\nIn discussing the released American hostages, Trump says,\n\n“We want to thank Kim Jong-un, who really was excellent to these three incredible people.” \n\nDeplorable. https://t.co/Pwytm387rR
# 10  Why doesn’t the Fake News Media state that the Trump Administration’s Anti-Trust Division has been, and is, opposed to the AT&amp;T purchase of Time Warner in a currently ongoing Trial. Such a disgrace in reporting!
# 11  George Will was never respected on the right. If we did an approval poll on him, he'd be in single digits. . . The rest would ask who the hell he is? These attacks on Mike Pence? So you don't like Trump because he's too brash, and you don't like Pence because he's too humble?
# 12  Once again, seems like Giuliani has accidentally confessed that Trump did something inaproppriate without either understanding that it’s inappropriate or even knowing if Trump did it or not. Helluva thing.
# 13  Esta vez es real: en Estados Unidos proponen a Donald Trump para el Nobel de la Paz. ¿Podría ganarlo?\n\nhttps://t.co/4G4SfMtk7k https://t.co/CamgzFbLPg
# 14  Two months ago, we asked the government to investigate whether Trump had an interest in Michael Cohen’s shell company, which we now know took in at least $4.4 million. If Trump benefited, that could land him in serious legal trouble.\nhttps://t.co/f1Mk2MTuTB
# 15  @ghurstley @PastorMikeHill1 @realDonaldTrump @FoxNews You should support President Trump! The Lord our God has sent him to us to save this country and this world. We The people have prayed for years to have someone so great to fix this mess. He has done more good than anyone since Reagan. If you don't see it is because you wont
# 16  I agree with u. I have the utmost respect for Sen. McCain's military service but I (clearly) do not endorse many of his political acts, particularly his relationship with the NRA. That said, he's led a rich and fascinating life &amp; I thought this was a compelling piece of writing. https://t.co/PmhpVCXysj
# 17  Obama dejó crecer lío nuclear Corea Norte, aceptó lo q Irán exigió, fue a Cuba a ver Béisbol con un criminal y ante tiranía de Chávez/Maduro, miró al costado. \n\n@realDonaldTrump Trump sentó a Corea Norte, anuló acuerdo Irán, desmontó acercamiento con Castro y presiona a Venezuela
# 18  45/ It does appear that Trump specifically obstructed Congress inquiries about whether he or any of his campaign affiliates had ever received loans from Bank of Cyprus, which is partly owned by a close ally of Putin. https://t.co/rJgDTjM84y
# 19  Well, well, well... https://t.co/hoXmZrahLy
# 20  The funny thing is Clinton said people who planned to vote for Trump were deplorable. So if you weren't going to vote for Trump anyway, you wouldn't see that as applying to you.\n\nIt's almost as if right wing voters who chose the racist are responsible for their own decisions. https://t.co/57Dtn0FUCm
# 21  #Iran Deal: #Trump's Pullout May Result in Three Scenarios, Benefits for #Russia: \nhttps://t.co/tQIXlljngT via @SputnikInt\n\n#irannucleardeal #jcpoa
# 22  @IngrahamAngle @realDonaldTrump Trump is the devil incarnate.
# 23  Did you read about Cohen's failed overture to Ford Motor? How many others were there? Extortion in violation of Title 18, U.S.C., Sec 1951 takes many forms; no physical threat is needed. Trump's public attacks on businesses/industries followed by Cohen's "offers" could qualify. https://t.co/e5PrHiOsF9
# 24  How LOW did Obama &amp; his admin go? \nThey friggin planted a spy into the Trump campaign! \nThe spy? Rush &amp; other sources are claiming it to be Stefan Halper, foreign policy scholar who served as a WH official in the Nixon, Ford, and Reagan admin! \nhttps://t.co/jZN8xA3YO3
# 25  @ShepRose Love ya Shep, but I hate Trump! You cannot believe one single thing he says ever, it's unfortunate, being a liar should not be part of being a president... so sad
# 26  Let this serve as formal notice - there is significantly more evidence and facts to come relating to Mr. Cohen's dealings and Mr. Trump's knowledge and involvement. You can come clean now or wait to be outed. Your choice. We have only just begun...#Basta
# 27  Why is Michele obama still going around talking about women voting for trump.. I'll vote for who I want to vote for.. I can't stand it when dudes try to tell me what I should and shouldn't do!
# 28  DEVELOPING: A major new front is opening in the political espionage scandal. In summer 2016, Brennan with his FBI liaison Strzok, along with help from Kerry @ State, were trying to set Russian espionage traps for minor players in the Trump campaign through cultivated intel assets
# 29  A Democratic House candidate in Pennsylvania deletes tweets blasting progressives and praising then-President-elect Donald Trump https://t.co/HntF8hPqS3 https://t.co/TVtuORrnjy
# 30  In tonight’s #WhatADay: Trump isn't even attempting to fulfill his campaign promise of using Medicare’s bargaining power to negotiate lower prescription drug prices https://t.co/MDgmfWaLwH
# 31  New #Deconstructed podcast: Did Donald Trump just take us one step closer to war with Iran? Featuring @TVietor08 and @mehdirhasan\nhttps://t.co/pgPGxwsWt3
# 32  Donald Trump won the White Evangelical Christian vote by a margin of 64 points, 80%-16%.\n\nIt's shameful these people demonized a decent man like Barack Obama and tirelessly praise an indecent, racist, bigoted, lying, adulterous man like Trump...
# 33  This is not a joke folks, and it shouldn't be taken like one.  Trump does not intend to ever give up power.  When he is done, he plans to pass leadership to Ivanka.  We need to take this repeated threat to our democracy very seriously. https://t.co/vvqvJINCoR
# 34  I’m driving in #Jerusalem right now and this is what it looks like! \n\nThere are “Trump Make #Israel Great” signs on the traffic lights, &amp; American flags flying next to Israeli flags all around the capital of Israel! \n\nIt’s an incredible sight to see! Thank you @realDonaldTrump! https://t.co/dbaSSL0QkN
# 35  At 3 a.m., Trump greeted the freed North Korean hostages.\n\nAt 7 p.m., he held a rally in Indiana.\n\nCould you imagine that fainting goat named Hillary trying to keep up with a fraction of his schedule?
# 36  A top State Department nuclear expert announced his resignation following Trump's Iran deal decision. The office he led at State, on Iran nuclear implementation, has now gone from 7 to 0 staffers. Scooplet from @columlynch and me: https://t.co/7W1CPvN4jd
# 37  @realDonaldTrump Let this serve as formal notice - there is significantly more evidence and facts to come relating to Mr. Cohen's dealings and Mr. Trump's knowledge and involvement. You can come clean now or wait to be outed. Your choice. We have only just begun...#Basta
# 38  @JeffreyGuterman I think Donald the Trump thought he was on Bill and Ted's Excellent Adventure and Kim Jong-un was really Excellent to people and not Bogus as he really is
# 39  #FBImole #FBICorruption https://t.co/8mdTbwCU9H
# 40  The crowd at Trump's rally in Elkhart, Indiana, has already chanted "Lock her up" repeatedly. \n\nIncidentally, Dutch lawyer Alex van der Zwaan, who pleaded guilty to lying to special counsel Robert Mueller's investigators, reported to prison to start his sentence today.
# 41  #WhiteLiesYouTellKids Donald Trump is under your bed.
# 42  Why doesn’t the Fake News Media state that the Trump Administration’s Anti-Trust Division has been, and is, opposed to the AT&amp;T purchase of Time Warner in a currently ongoing Trial. Such a disgrace in reporting!
# 43  Let this serve as formal notice - there is significantly more evidence and facts to come relating to Mr. Cohen's dealings and Mr. Trump's knowledge and involvement. You can come clean now or wait to be outed. Your choice. We have only just begun...#Basta
# 44  the independent will be writin these gimpy articles aboot jk rowling for fuckin years after she dies\n\n‘we spoke to the worms who ate JK Rowling’s flesh and we are LIVING’\n‘we just saw JK Rowling’s ghost in the carpark; ‘she said hermione was actually a beyblade this whole time’’ https://t.co/QsoJ4SY91F
# 45  @TheRickyDavila Giuliani is a has been, crook, mafioso. He’s Trumps little bitch... there’s footage of him in drag being a little biatch. So ya.. I’d say he’s been pumped out by trump. Guess rule number 1 is to not upset your John. Of course he won’t debate.
# 46  Scoop: I’m told multiple high-level Trump outside advisors have alerted the President to WH staffer Uttam Dhillon’s leak of the Mueller questions and close ties to James Comey, describing him as a “mole” within the White House
# 47  If what you really want is what Donald Trump is, what he does, what he says, how he says it, his values, his vision of and for this country—I don't know what country you want to live in, or what country you want this to be, but it's not America as we've known it for 242 years.
# 48  Why doesn’t the Fake News Media state that the Trump Administration’s Anti-Trust Division has been, and is, opposed to the AT&amp;T purchase of Time Warner in a currently ongoing Trial. Such a disgrace in reporting!
# 49  DAMN RIGHT, GARY!!!! #VoteBlueNoMatterWho https://t.co/6UAh4IZ5SL
#
#    sentiment        SA  Subjective
# 0   Negative  Positive  0.454545
# 1   Negative  Negative  0.000000
# 2   Negative  Negative  0.000000
# 3   Negative  Positive  0.700000
# 4   Negative  Positive  0.591667
# 5   Negative  Positive  0.400000
# 6   Negative  Positive  0.592708
# 7   Negative  Negative  0.716667
# 8   Negative  Positive  0.361111
# 9   Negative  Positive  0.458333
# 10  Negative  Negative  0.633333
# 11  Negative  Negative  0.512500
# 12  Negative  Negative  0.000000
# 13  Negative  Positive  0.300000
# 14  Negative  Negative  0.366667
# 15  Negative  Positive  0.506250
# 16  Negative  Positive  0.452083
# 17  Negative  Negative  0.550000
# 18  Negative  Negative  0.000000
# 19  Negative  Negative  0.000000
# 20  Negative  Positive  0.797143
# 21  Negative  Negative  0.000000
# 22  Negative  Negative  0.000000
# 23  Negative  Positive  0.301361
# 24  Negative  Negative  0.266667
# 25  Negative  Negative  0.742857
# 26  Negative  Positive  0.733333
# 27  Negative  Negative  0.000000
# 28  Negative  Positive  0.250909
# 29  Negative  Positive  0.900000
# 30  Negative  Negative  0.000000
# 31  Negative  Positive  0.454545
# 32  Negative  Positive  0.222222
# 33  Negative  Negative  0.866667
# 34  Negative  Positive  0.437143
# 35  Negative  Negative  0.000000
# 36  Negative  Positive  0.300000
# 37  Negative  Positive  0.733333
# 38  Negative  Positive  0.733333
# 39  Negative  Negative  0.000000
# 40  Negative  Negative  0.785714
# 41  Negative  Negative  0.000000
# 42  Negative  Negative  0.633333
# 43  Negative  Positive  0.733333
# 44  Negative  Positive  0.208333
# 45  Negative  Negative  0.356944
# 46  Negative  Positive  0.147500
# 47  Negative  Positive  0.350000
# 48  Negative  Negative  0.633333
# 49  Negative  Positive  0.535714

# %%
import pickle

def load_pickle(file_name):
    with open(file_name + '.pickle', 'rb') as file:
        classifier = pickle.load(file)
    return classifier

# %%
classifier = load_pickle('vec_clf')

# %%
# classifier.score(data_test, targets_test)
# predicted = classifier.predict(vectorized_data)
print(classifier)
def sentiment2target(sentiment):
    return {
        'Negative': 0,
        'Positive' : 1
    }[sentiment]

# Convert Classification into integer for speed and space efficiency reasons
targets_SA = df.SA.apply(sentiment2target)
targets_sentiment = df.sentiment.apply(sentiment2target)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#        ...',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
predicted = classifier.predict(df.text)

# %%
np.mean(predicted == targets_SA)
# Out:
# 0.5821330902461258

# %%
np.mean(predicted == targets_sentiment)
# Out:
# 0.945123062898815

# %%
count_pre = 0
count_pos = 0
for pre in predicted:
    if pre == 1:
        count_pos += 1
        print(df.text[count_pre])
        print("")
    count_pre += 1
# Out:
# I’m driving in #Jerusalem right now and this is what it looks like!
#
# There are “Trump Make #Israel Great” signs on the traffic lights, &amp; American flags flying next to Israeli flags all around the capital of Israel!
#
# It’s an incredible sight to see! Thank you @realDonaldTrump! https://t.co/dbaSSL0QkN
#
# @JeffreyGuterman I think Donald the Trump thought he was on Bill and Ted's Excellent Adventure and Kim Jong-un was really Excellent to people and not Bogus as he really is
#
# Mike Pence: “It’s time to wrap up the Mueller investigation.”
#
# — Trump campaign had 70 contacts &amp; 22 meetings w/ Russia.
#
# — 13 Russians indicted &amp; 3 Trump advisors have pled guilty.
#
# — Trump fired Comey &amp; confessed it was b/c of Russia.
#
# It’s time to wrap up the Trump presidency.
#
# Thanks to JW's efforts holding Special Counsel Mueller accountable, JW found docs showing bias among DOJ officials like Andrew Weissmann (top prosecutor on the Mueller team) praising Obama DOJ holdover Sally Yates for lawlessly thwarting President Trump. https://t.co/fw7xXgNniv
#
# A Trump administration staffer denigrates John McCain without any condemnation. Every day I say, “Trump can’t go any lower”…and every day, he does.
#
# I’m driving in #Jerusalem right now and this is what it looks like!
#
# There are “Trump Make #Israel Great” signs on the traffic lights, &amp; American flags flying next to Israeli flags all around the capital of Israel!
#
# It’s an incredible sight to see! Thank you @realDonaldTrump! https://t.co/dbaSSL0QkN
#
# ✅ RE-ELECT Devin Nunes for Congress!!
#
# Nunes has a PROVEN Record for STANDING
# With 🦅President Trump!
#
# Please Support &amp; Follow 👉.@DevinNunes
#
# Let's #MakeCaliforniaGreatAgain #CA22
#
# #FlipCARed 🔴🇺🇸
# #ArmyOfTrump 🇺🇸
# #MakeCaliGreatAgain🇺🇸
#
# https://t.co/WPzX0aK7dX https://t.co/WKKwtOlUQM
#
# Even though I'm upset with John McCain &amp; his feud with President Trump, the man still served his country &amp; did some great things while doing so.
#
# With the time he has left, I feel it's important to speak up &amp; give him the credit he deserves for his POW sacrifices. #USAVets🇺🇸
#
# The best thing I've seen on TV in a long time. Steve Schmidt's comparison of a hero named John McCain and a coward named Donald Trump. @SteveSchmidtSES @votevets @NicolleDWallace @MeghanMcCain @cindymccain @kellysadler45 @Veterans @vets @NavalInstitute @USNavy @fbi @amvetsupport https://t.co/pHK1e4Px4k
#
# I was with a renowned German scientist today who said it’s more important now than ever that Europe stay united &amp; work together to hold things together in the world as Trump tries to tear things apart. Europe has to work together &amp; work around the US for the good of the world.
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# Except for President Trump’s success, nothing has the Democratic Party more scared right now than the free thinking Kanye West and Candace Owens have unleashed upon African-Americans.
#
# It’s incredible to watch this sweeping culture change. Good luck with that “Blue Wave.”
#
# @Rep_Hunter blaming sleazy guys who work for Trump for all the collusion stuff.  @billmaher says "thank you for your service.  I hope you lose your next election" #CA50
#
# Yes I was on The Trump Train Day One. I’d follow him to Hell and Back. If the day comes when we need to Fight and if necessary DIE for him Ill Be In That Fight and Die Fighting in a Big Pile Of Hot Brass https://t.co/rh0gVRW0OL
#
# I'm ordering a brand new shirt with TRUMP written huge on it for when I'm walking through the airports next weekend.
#
# I'll make sure to walk really slowly, so everyone can see this loud and proud Trump supporter. 😂
# #FridayFeeling
#
# @sodergrengirl @BaconGrillin123 @dkbufny @ryanjreilly Besides Trump's own tweets, Giuliani is the best thing to hsppen to the Mueller investigation !
#
# “President Trump has done more to help the American Economy in his first year than Obama ever did.”~@WayneDupreeShow #TeamWD
#
# #RealTalk delivered by Wayne, interviewer of  @realDonaldTrump 5x’s
#
# READ WHAT MAD @RepMaxineWaters IS SAYING 👇🏻👇🏻 https://t.co/JOQOtWXmgI
#
# 🚨REMEMBER: To ride TRUMP FORCE ONE, you must follow ALL &amp; followback patriots: don't disappoint! We have to stick together!🇺🇸
# ✔️ALWAYS take time to VOTE! ✔️
# ✈️ We support our WINNING President! ✈️
# 👩‍✈️Until next time, take care, my fellow patriots!👩‍✈️ https://t.co/uoytYZg2pe
#
# Except for President Trump’s success, nothing has the Democratic Party more scared right now than the free thinking Kanye West and Candace Owens have unleashed upon African-Americans.
#
# It’s incredible to watch this sweeping culture change. Good luck with that “Blue Wave.”
#
# 🙏GOOD NIGHT PATRIOTS🙏
# GOD HAS PRESIDENT TRUMP'S BACK 💯WHAT A WEEK FOR AMERICA🙏SO
# MUCH LOVE &amp; WINNING AGAINST ALL ODDS🙏🇺🇸
# PATRIOTS WE ROCKED TWITTER SPREADING THE
# GOOD NEWS💥LOVE EACH OTHER GOD &amp; COUNTRY
# ALWAYS &amp; FOREVER A PATRIOT💯
# 🙏🇺🇸🙏🇺🇸🙏🇺🇸🙏🇺🇸 https://t.co/cAu28EsuG7
#
# Steve Schmidt on @DeadlineWH with @NicolleDWallace today:
#
# "I've never seen such slobbering servility" regarding Mike Pence's relationship with Trump.
#
# I love @SteveSchmidtSES and need him on my TV often!
#
# I liked a @YouTube video https://t.co/fszJ1nqSiI Trump's Chief Of Staff Has Some Thoughts On Hispanics...
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# @KellyannePolls Hi kellyanne im on my ninth year of a brain injury and ive come along way im determined to beat it,potus trump is my hero and idol and he inspired me to recover im not a quitter and im a fight its my dream to meet potus and flotus and tell him what he has done for me.
#
# interesting/// https://t.co/uvnPm6YpKV
#
# Optimism In America Hits A 11 Year High Under Trump’s Presidency
#
# Sounds Like Winning For America 🇺🇸 To Me !!
#
# #MAGA #KeepAmericaGreat #FridayFeeIing #SaturdayMorning #SaturdayMotivation #SundayFunday
#
# Follow this great Patriot👉 @AMErikaNGIRLBOT
#
# https://t.co/kEmOKhEiOH https://t.co/QmOpz3whq6
#
# Salena Zito's 'The Great Revolt' presents Trump voters in their own words https://t.co/Ofgn6c5vZ7
#
# Interesting theme developing here: companies/industries Trump had explicitly talked tough about during the campaign (drug prices, cars being built in Mexico, ATT merger) https://t.co/K8QGAOl6GV
#
# Trump's message to Kim.
#
# You will never be a great nuclear power, but if you give up your nukes, I'll help you become a great economic power.
#
# While Pres. Obama’s first circuit court nominees were approved with overwhelming bipartisan votes, Pres. Trump has largely put forward controversial nominees outside the mainstream. 10 of President Trump’s first 15 circuit court nominees were confirmed with fewer than 60 votes.
#
# Mike Pence: “It’s time to wrap up the Mueller investigation.”
#
# — Trump campaign had 70 contacts &amp; 22 meetings w/ Russia.
#
# — 13 Russians indicted &amp; 3 Trump advisors have pled guilty.
#
# — Trump fired Comey &amp; confessed it was b/c of Russia.
#
# It’s time to wrap up the Trump presidency.
#
# Everyone who hates on Trump and calls Elkhart trash doesn’t actually know anything about politics and what he’s done butttt oh well people just stay ignorant. Steady calling Elkhart trash when it’s doing the best it has ever done lmaoooo
#
# @supertalk @cindyhydesmith @realDonaldTrump @thejtshow cant stand trump. at all.  hate everything about him, BUT, he's probably right about this one. he was right about pakistan,too.  ill give him his due..
#
# @IngrahamAngle trump received the Ellis island award in 1986
#
# Interesting take from a Trump supporter. https://t.co/WF4FDzPdY0
#
# Wow!  "Peace is the prize"
# LOVE our @POTUS !!!! https://t.co/71VmArjuca
#
# Tucker Carlson and Dan Bongino on the FBI mole inside the Trump campaign. Hard to believe Comey, Lynch and Obama were this reckless during a presidential election campaign.
# https://t.co/vOy2ExT8Bc
#
# @realDonaldTrump @aliatra1968 Your the best President Trump!! Americans eyes are starting to open and the left knows this. Keep doing what your doing, America needs you!
# @realDonaldTrump
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# More #Winning!
# Poll: Optimism in Direction of Country Hits 11-Year High Under Trump! Despite #FakeNews, we are unifying behind our President!
# #golfinggary
#  https://t.co/lcMTYNlbps via @BreitbartNews
#
# Oh. My. God.
# (After @Rep_Hunter defended Trump’s Russian treason on #RealTime).
# #Bill Maher:  You’re a good guy.
# Duncan: Thank you for having me.
# Maher: ...and I hope you lose your election.  Thank you for your service.  💥
#
# Good stuff here.  This well connected patriot knows his stuff.
#
# Follow --&gt; @JackPosobiec &lt;--
#
# #TheGreatAwakening https://t.co/Rx1z7MsUjt
#
# 🙏GOOD NIGHT PATRIOTS🙏
# GOD HAS PRESIDENT TRUMP'S BACK 💯WHAT A WEEK FOR AMERICA🙏SO
# MUCH LOVE &amp; WINNING AGAINST ALL ODDS🙏🇺🇸
# PATRIOTS WE ROCKED TWITTER SPREADING THE
# GOOD NEWS💥LOVE EACH OTHER GOD &amp; COUNTRY
# ALWAYS &amp; FOREVER A PATRIOT💯
# 🙏🇺🇸🙏🇺🇸🙏🇺🇸🙏🇺🇸 https://t.co/cAu28EsuG7
#
# @msellemaldonado Totally agree with you. Dislike trump but love this show.
#
# Trump's somewhat embarrassed in spite of his shamelessness https://t.co/NaJ3nLhkrk
#
# What will make Trump the greatest POTUS in history?
#
# 🔺He’s an American first.
# 🔺He has his priorities straight.
# 🔺He literally wrote the book on making deals.
# 🔺He speaks the truth.
# 🔺He’s keeping nuclear weapons out of the wrong hands.
# 🔺He’s MAKING AMERICA GREAT AGIAN!🇺🇸 https://t.co/QAAfGVAr6k
#
# I liked a @YouTube video https://t.co/u1PPYhJnJL Trump's Chief Of Staff Has Some Thoughts On Hispanics...
#
# WATCH: Trump Supporter Goes Viral For Schooling CA City Council On Immigration, Audience ERUPTS https://t.co/9hzIeXhcIN
#
# Mike Pence: “It’s time to wrap up the Mueller investigation.”
#
# — Trump campaign had 70 contacts &amp; 22 meetings w/ Russia.
#
# — 13 Russians indicted &amp; 3 Trump advisors have pled guilty.
#
# — Trump fired Comey &amp; confessed it was b/c of Russia.
#
# It’s time to wrap up the Trump presidency.
#
# @Watershedd @actgovernment @abcnews @GuardianAus @AJENews @AusFedPolice @EY_Australia @Actgoverment Is this the reason people had to act so hastily &amp; illegally to get rid of Mullins, had the trump been played, so he had to go? Note pt 2: Thevt and transfer of ACT Government Assets to Rosefort Pty Ltd... not forgetting to point out the stamp on the bottom. Mullins won case 16-0 https://t.co/weDznyKk0i
#
# I’m driving in #Jerusalem right now and this is what it looks like!
#
# There are “Trump Make #Israel Great” signs on the traffic lights, &amp; American flags flying next to Israeli flags all around the capital of Israel!
#
# It’s an incredible sight to see! Thank you @realDonaldTrump! https://t.co/dbaSSL0QkN
#
# @molratty Why Trump won.
#
# I'm ordering a brand new shirt with TRUMP written huge on it for when I'm walking through the airports next weekend.
#
# I'll make sure to walk really slowly, so everyone can see this loud and proud Trump supporter. 😂
# #FridayFeeling
#
# @PalmerReport @realDonaldTrump Thank you President Trump for the hard work you’re doing for the American People by putting #AmericaFirst -every American benefits and improving healthcare to meet everyone’s needs is what we want/ we don’t listen to Leftist pundits that only care about votes for a leftist agenda
#
# 🙏GOOD NIGHT PATRIOTS🙏
# GOD HAS PRESIDENT TRUMP'S BACK 💯WHAT A WEEK FOR AMERICA🙏SO
# MUCH LOVE &amp; WINNING AGAINST ALL ODDS🙏🇺🇸
# PATRIOTS WE ROCKED TWITTER SPREADING THE
# GOOD NEWS💥LOVE EACH OTHER GOD &amp; COUNTRY
# ALWAYS &amp; FOREVER A PATRIOT💯
# 🙏🇺🇸🙏🇺🇸🙏🇺🇸🙏🇺🇸 https://t.co/cAu28EsuG7
#
# I'm in.  #MAGA Michael Avenatti Great American. @MichaelAvenatti https://t.co/zKz2lcf1wi
#
# I followed all you Patriots. I support President Trump, border wall, NRA. #MAGA
# Thank you for all follow backs https://t.co/1nyjYEuaGt
#
# thank you mr trump
# @POTUS https://t.co/7p1IoaIS6G
#
# Interesting theme developing here: companies/industries Trump had explicitly talked tough about during the campaign (drug prices, cars being built in Mexico, ATT merger) https://t.co/K8QGAOl6GV
#
# .@KatrinaPierson: "Donald Trump was a man who packed stadiums like a championship game during the campaign and mainly it was because of his unapologetic patriotism. He made it okay to be a proud American." https://t.co/2zbGyZgjn9
#
# While Pres. Obama’s first circuit court nominees were approved with overwhelming bipartisan votes, Pres. Trump has largely put forward controversial nominees outside the mainstream. 10 of President Trump’s first 15 circuit court nominees were confirmed with fewer than 60 votes.
#
# AND HELL IS WAITING FOR THIS TRAITOR I HOPE HE SUFFERS WHILE HE IS DYING AND FEEL THE FLAMES FROM HELL THAT WILL BURN HIM FOR EVER https://t.co/AJ8Zrq8OcW
#
# in 08 the left hated McCain, now they love referring to him as a "hero" all bc he hates Trump
#
# I’m driving in #Jerusalem right now and this is what it looks like!
#
# There are “Trump Make #Israel Great” signs on the traffic lights, &amp; American flags flying next to Israeli flags all around the capital of Israel!
#
# It’s an incredible sight to see! Thank you @realDonaldTrump! https://t.co/dbaSSL0QkN
#
# Democratic party sues Russia, Wikileaks &amp; Trump campaign over election disruption
# https://t.co/8qDLxZdSHj
#
# DNC LAWSUIT OVER TRUMP CONSPIRACY INVOLVING WIKILEAKS &amp; MUH RUSSIA
#
# Q WAS RIGHT AGAIN!
#
# They ARE SCARED &amp; FALL for the TRAP!
#
# SO AWESOME!
#
# WINNING
#
# Thanks Q &amp; @POTUS!
#
# #MAGA https://t.co/1O3842sjwC
#
# You don’t have to agree with everything John McCain has done to appreciate @SteveSchmidtSES’s blistering takedown of Trump and the people around him. https://t.co/suADHIBHo8
#
# Rush👉Nails It💥
#
# According to Limbaugh, the Mueller probe has the purpose of covering up efforts by the Obama Department of Justice and FBI to taint Donald Trump’s presidency.
#
# Yup, Rush Is Right AGAIN
#
# #MAGA #KeepAmericaGreat
# Follow @AMErikaNGIRLBOT
#
# https://t.co/lIC1wAwxMg https://t.co/W9ltEXAvbS
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# More #Winning!
# Poll: Optimism in Direction of Country Hits 11-Year High Under Trump! Despite #FakeNews, we are unifying behind our President!
# #golfinggary
#  https://t.co/lcMTYNlbps via @BreitbartNews
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# Which is why #RealDonalTrump won the 2016 election, and will win again in 2020. And if We The People vote out Rhinos this Nov. and elect real conservatives to House &amp; Senate to help @POTUS, America will win even more. https://t.co/ShQI6QzZQz
#
# @AlexAloha67 @realDonaldTrump @netanyahu I love how many form a prayer circle &amp; lay hands on President Trump. #WWG1WGA #QAnon 🇺🇸👌
#
# @SenateDems This is a joke right?  Trump has done more for this country in one year than Obama in 8
#
# Attention Patriots!!!! 🇺🇸 Michael is best-Fun-FakeNews Follow!  If you love to laugh this is your guy!  He’s a an awesome Trump supporter! https://t.co/pCuBQhWm02
#
# Trump’s action in pulling out of the Iran deal makes sense primarily as a trillion-dollar gift to Putin (by boosting Russia’s take from the oil market) in exchange for Putin’s many favors to Trump — like helping him win the presidency and indirectly bailing him out of his debts.
#
# I’m driving in #Jerusalem right now and this is what it looks like!
#
# There are “Trump Make #Israel Great” signs on the traffic lights, &amp; American flags flying next to Israeli flags all around the capital of Israel!
#
# It’s an incredible sight to see! Thank you @realDonaldTrump! https://t.co/dbaSSL0QkN
#
# Optimism In America Hits A 11 Year High Under Trump’s Presidency
#
# Sounds Like Winning For America 🇺🇸 To Me !!
#
# #MAGA #KeepAmericaGreat #FridayFeeIing #SaturdayMorning #SaturdayMotivation #SundayFunday
#
# Follow this great Patriot👉 @AMErikaNGIRLBOT
#
# https://t.co/kEmOKhEiOH https://t.co/QmOpz3whq6
#
# Except for President Trump’s success, nothing has the Democratic Party more scared right now than the free thinking Kanye West and Candace Owens have unleashed upon African-Americans.
#
# It’s incredible to watch this sweeping culture change. Good luck with that “Blue Wave.”
#
# Lord, Please reveal all of the Treasonous devils who have tried to overturn the election of President Trump. Bring their evil plans to naught and bring them to justice, in Jesus name Amen.
#
# @realDonaldTrump Another massive rally where our president speaks directly to the people.
#
# The great state of Indiana is TRUMP COUNTRY! https://t.co/RKoQJ1kx5J
#
# @SkyAcresFarm Hey Diamond and Silk🌹I LOVE YOU GIRLS!🙏GOD BLESS YOU FOR WORKING TO HELP PRES. TRUMP MAKE AMERICA GREAT!You both are doing a GREAT JOB SUPPORTING THE GREATEST PRESIDENT IN U.S. HISTORY! I get tired of hearing Liberal demwits because they lost! We are doing so well I don't care!
#
# @thehill The ENTIRE Trump Administration needs to be in Trumps words "FIRED" including Trump himself. They dont act like adults let alone professionals a normal person who has common sense doesnt act like this and support anyone saying this stuff. I would do this at my job I'm FIRED!
#
# @SenFeinstein @JudiciaryDems Thank God. That's what we voted for. The less demoncRATS the better. Love Trump's picks
#
# Malcome is the best, thanks for telling it as it should be.ts disgraceful that a president badly treats someone like John McCain.I have policy differences with Sen McCain but have never questioned his devotion to country. On the other hand, I have with @realDonaldTrump every day https://t.co/9k9kJMNKpL
#
# “Donald Trump was a man who packed stadiums like a championship game during the campaign and mainly it was because of his unapologetic patriotism. He made it okay to be a proud American."~@KatrinaPierson https://t.co/fNxEs3HWSU
#
# You don't have to agree with trump but the mob can't make me not love him. We are both dragon energy. He is my brother. I love everyone. I don't agree with everything anyone does. That's what makes us individuals. And we have the right to independent thought.
#
# Some Q drops about our President! He willingly takes these slings and arrows for us!  God bless and protect President Trump, Melania, each member of their family, each member of the Q Team, &amp; our great military! #QAnon @realDonaldTrump @FLOTUS https://t.co/msk6a7k1o7
#
# @dcassepoolman @lftbronson @wahwahguy @wolfeatworld @Tattoobear @Landilamb @firemandon68 @andersonDrLJA @treed1955 @bratNvet @jazzi_mae @America1stMae @StrainDoug @sweetpea2k There are some #Awesome Patriots riding the Trump Train with @realDonaldTrump. We are #MAGA each and everyone of us with our support of our President 45.  I love being part of the movement.
#
# North Korea releases prisoners in good faith gesture for Trump summit. And the response from Democrats? Crickets... 🦗🦗🦗🦗 https://t.co/yUbzM23niq
#
# Interesting theme developing here: companies/industries Trump had explicitly talked tough about during the campaign (drug prices, cars being built in Mexico, ATT merger) https://t.co/K8QGAOl6GV
#
# A Trump administration staffer denigrates John McCain without any condemnation. Every day I say, “Trump can’t go any lower”…and every day, he does.
#
# @BFoxForBernie @HillaryClinton Crypto Bernie, thank you. Because of people like you we have Trump in the WH. Good job.  You have actually topped the Nader supporters that gave us W and decades of wars in the Middle East.  When trump gets to a few more life time Appointments to the SC you will be so proud
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# This is definitely not my best picture (he got my wrong side hah)  but I'm proud to be a Mexican-American Woman who puts her country first. Thanks for the fame, Jim; you made my first Trump Rally experience a lot better! https://t.co/gqnHe8N6gR
#
# GOOD NIGHT🇺🇸PATRIOTS WE ROCKED TWITTER WITH DYANOMITE POST
# 🙏CAN'T STRESS HOW IMPORTANT WE STAND UP WITH PRESIDENT TRUMP
# I WATCHED LAST 10YRS OF TRUMP INTERVIEWS/ CHAMPION FOR USA 💯 LOVED THE PEOPLE/WR'RE THE REASON HE FIGHTS DAILY
# #TrumpsArmy
# #ALWAYS &amp; FOREVER A
# PATRIOT💯 https://t.co/z9CmfmxxKr
#
# Interesting theme developing here: companies/industries Trump had explicitly talked tough about during the campaign (drug prices, cars being built in Mexico, ATT merger) https://t.co/K8QGAOl6GV
#
# @strictlymagsy @BarbraStreisand He won because of Russia Hillary actually won the popular vote Trump has done nothing !!!! He has no clue what he is doing and it shows everyday
#
# "Indeed, the remaining anti-Trump voices on the Right seem more desperate than ever to take down the president, if only to prove that, actually, they were right all along."
#
# Can We All Finally Admit Trump Is A Good President? https://t.co/on85pNwTg1
#
# I'm ordering a brand new shirt with TRUMP written huge on it for when I'm walking through the airports next weekend.
#
# I'll make sure to walk really slowly, so everyone can see this loud and proud Trump supporter. 😂
# #FridayFeeling
#
# @HeyNikki1 Maher is closer to Trump and Kanye than he would care to admit. Free-thinker anti-PC smugness. #RealTime
#
# Woo-hoo!!! I love you, @Atheen_! https://t.co/tMlGZq4ppj
#
# I’m driving in #Jerusalem right now and this is what it looks like!
#
# There are “Trump Make #Israel Great” signs on the traffic lights, &amp; American flags flying next to Israeli flags all around the capital of Israel!
#
# It’s an incredible sight to see! Thank you @realDonaldTrump! https://t.co/dbaSSL0QkN
#
# "Indeed, the remaining anti-Trump voices on the Right seem more desperate than ever to take down the president, if only to prove that, actually, they were right all along."
#
# Can We All Finally Admit Trump Is A Good President? https://t.co/on85pNwTg1
#
# Attention Patriots!!!! 🇺🇸 Michael is best-Fun-FakeNews Follow!  If you love to laugh this is your guy!  He’s a an awesome Trump supporter! https://t.co/pCuBQhWm02
#
# One of my best friends in the world is from Iran. He had to flee in the early 1980s, when the brutal Islamic regime executed 4 of his friends.
#
# He is so proud of President Trumps decision to not tolerate the brutal killers in Iran. Trump is doing what must be done for World Peace
#
# Donald Trump winning the Nobel Peace Prize will go a long way to restoring it as a great honor, rather than a meaningless trophy elitists hand out to each other.
#
# Retweet if you agree.
#
# What will make Trump the greatest POTUS in history?
#
# 🔺He’s an American first.
# 🔺He has his priorities straight.
# 🔺He literally wrote the book on making deals.
# 🔺He speaks the truth.
# 🔺He’s keeping nuclear weapons out of the wrong hands.
# 🔺He’s MAKING AMERICA GREAT AGIAN!🇺🇸 https://t.co/QAAfGVAr6k
#
# A Trump administration staffer denigrates John McCain without any condemnation. Every day I say, “Trump can’t go any lower”…and every day, he does.
#
# More #Winning!
# Poll: Optimism in Direction of Country Hits 11-Year High Under Trump! Despite #FakeNews, we are unifying behind our President!
# #golfinggary
#  https://t.co/lcMTYNlbps via @BreitbartNews
#
# Trump doesn't just answer the call at 3am to save Americans, unlike Obama/Clinton, he actually greets them at the airport to welcome them home from captivity.👏
#
# Thank you @POTUS Trump for exceeding our expectations of #MAGA #AmericaFirst #KAG!
#
# #WINNING👌
# https://t.co/qi1njqFSL5
#
# EVERYONE RETWEET THESE PICTURES BECAUSE THE LEFT WING MEDIA DOESN’T WANT YOU TO SEE THAT TRUMP IS LOVED IN ISRAEL!!!
#
# Seriously. There are Trump signs and American flags EVERYWHERE IN ISRAEL! The media doesn’t want to admit Trump is doing a great job.
#
# Cc: @realDonaldTrump https://t.co/HRFDBTzgkL
#
# Mike Pence: “It’s time to wrap up the Mueller investigation.”
#
# — Trump campaign had 70 contacts &amp; 22 meetings w/ Russia.
#
# — 13 Russians indicted &amp; 3 Trump advisors have pled guilty.
#
# — Trump fired Comey &amp; confessed it was b/c of Russia.
#
# It’s time to wrap up the Trump presidency.
#
# Democratic House candidate in Pennsylvania deletes tweets blasting progressives, praising Trump @CNNPolitics #wiunion #wiright #wipolitics https://t.co/z23IoKjDHo
#
# @realDonaldTrump GO TRUMP!
#
# Thank You to all Trump Train followers, I can't beleive it, have gotten 323 Trump followers in 5 days.  Thanks again !
#
# #Barack #Obama, arguably the #worstpresident in US history, was wiretapping and listening in on all of the Trump campaign and transition team calls.
# And his Deep State minions had a spy inside the #Trump campaign!
#
# #FridayFeeIing #WeAreFree #TrumpLove https://t.co/vzqqocZ655
#
# Except for President Trump’s success, nothing has the Democratic Party more scared right now than the free thinking Kanye West and Candace Owens have unleashed upon African-Americans.
#
# It’s incredible to watch this sweeping culture change. Good luck with that “Blue Wave.”
#
# A Trump administration staffer denigrates John McCain without any condemnation. Every day I say, “Trump can’t go any lower”…and every day, he does.
#
# @joncoopertweets He should thank trump
#
# @Megavolts001 @mommofour @Deano04941 @491_678 @TroyMGood1 @CNNZfakenews @dawsonabner7 @PetersCongress @CookCharles @erikdixon34 @smitten_w I just love how Trump triggers all these fools! It’s a great time to be alive!! 💥🇺🇸 #MAGA #KAG https://t.co/BFZ28LRpwr
#
# @MichaelAvenatti I love you man, keep dropping cohens payments and the connection to trump every week, make Trump freak out in front of his tv, like he did to Hillary  with his conspiracy with russian hackers who destroyed our election with stolen info on Hillary. Keep up the Great investigation!
#
# I'm ordering a brand new shirt with TRUMP written huge on it for when I'm walking through the airports next weekend.
#
# I'll make sure to walk really slowly, so everyone can see this loud and proud Trump supporter. 😂
# #FridayFeeling
#
# Interesting theme developing here: companies/industries Trump had explicitly talked tough about during the campaign (drug prices, cars being built in Mexico, ATT merger) https://t.co/K8QGAOl6GV
#
# Grenell isn’t the only place #TeamTreason intersects with global human trafficking operations. tRUmp Org has enabled (and in some cases participated in) the ugliest trades on earth. People will be shocked when it comes out. And it will come out. Bet on it. https://t.co/wtkD8NO8hp
#
# https://t.co/A95ZbKwLBc
#
# It's nice to see the Big Voice on the Right finally say what we've been saying for a year now.
#
# Welcome aboard, @rushlimbaugh.
#
# #GreatAwakening
# #FridayFeeling
# #AwakenToMAGA
# #Midterms2018
# #UnitedWeMAGA
# #KAG
#
# Trump’s action in pulling out of the Iran deal makes sense primarily as a trillion-dollar gift to Putin (by boosting Russia’s take from the oil market) in exchange for Putin’s many favors to Trump — like helping him win the presidency and indirectly bailing him out of his debts.
#
# Except for President Trump’s success, nothing has the Democratic Party more scared right now than the free thinking Kanye West and Candace Owens have unleashed upon African-Americans.
#
# It’s incredible to watch this sweeping culture change. Good luck with that “Blue Wave.”
#
# One of the reporters who has done a great job tracking how Republicans blocked judicial seats under Obama and are filling them under Trump is @jbendery. Follow her. https://t.co/EbiIEjZsdD
#
# Pres Trump continues making history! I’m ready to stand with you to make American history on the Congressional front by being the first woman to hold a US Senate seat from the Great State of NJ! Would love to discuss exciting potential for women’s initiatives @IvankaTrump @POTUS https://t.co/dTWe2dqyYu
#
# Trump was reportedly upset about illegal border crossings and berated and yelled at Homeland Security Secretary Kirstjen Nielsen at Wednesday's cabinet meeting. She drafted a resignation letter and is described as "miserable" in her job. https://t.co/cvJHLqsrFG
#
# The following opinion deserves close attention and will certainly be the subject of a separate tweet. Stay tuned, Trump nation! https://t.co/wPi19zeScF
#
# @ErikErikdavid @ItsMeCathi @Charger0843Rion But hey, "it got the best ratings for late night tv" THAT is the only thing trump gives a dam about. It's constant tweeting, and interviews mentioning ratings and crowd size with this guy. He always said during the campaign,"even bad media coverage, is good media coverage"  .
#
# @thehill trump only gets the best people
#
# @SenJohnMcCain You tried your best to destroy the US and our duly elected President, and as usual you failed. Say what you will Mr McCain, but when you finally meet your maker DONALD J TRUMP WILL STILL BE YOUR PRESIDENT!! 😂😂😂 #karma
#
# Some amazing Anti-Trump voices that you want to follow, RT, follow &amp; share this list!
#
# @KamalaHarris
# @tedlieu
# @TeaPainUSA
# @ProudResister
# @sahluwal
# @SenWarren
# @SethAbramson
# @RepMaxineWaters
# @SenDuckworth
# @SenSanders
# @AdamSchiffCA
# @SaysHummingbird
# @CREWcrew
#
# #TheResistance
#
# Trump has arrived at Trump National Golf Club in Sterling, VA, according to the pool report.
#
# This is Trump's 154th day at a Trump property as president and his 112th day at a Trump golf club as president.
#
# This is great!  Trump and Q taught the world how to win without firing a gun, while still keeping the 2nd Amendment.  The truth will set us all free! https://t.co/hLNurzigOV
#
# Trump: Day 477
# -112th Day at a Trump Golf Club
# -154th Day at a Trump Property
# -Upset Mocking Comment Leaked
# -Thanks NK 4 Collapsed Test Site
# -Lifts Sanctions 4 Putin-Linked Firm
# -Killed Greenhouse Gas Monitoring
# -Has Giuliani Walk Back Comments
# -Orders FDA 2 Only Watch FOX News https://t.co/1j3VCbMuRQ
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# HERE IS MY DONALD TRUMP SUPPORTER RALLY SONG BY HENRY DAVIS!!!! THANKS FOR THE LOVE AND SUPPORT!!
# @RealCandaceO @DiamondandSilk @kanyewest @THEHermanCain @realDonaldTrump @RealVinnieJames @seanhannity @KimKardashian https://t.co/7dClINO9RX
#
# @TrumpQAnon @realDonaldTrump @flowers3712 @caramastrey @memom2010 @LexiHunting @Maggieb1B @Greggorj @Gatsbah Thank you.  I raised 6, all voted Trump in 2016 ❤, one more to go (18 next year)
#
# Whatever: #Trump's somewhat embarrassed in spite of his shamelessness https://t.co/Mf5R81Xxse
#
# It's great🤣🤣👏👏👏
# #trumpForPrison https://t.co/ZkDN4Q0HqJ
#
# @realDonaldTrump California calling.   Awesome job with North Korea!  Please lend a hand with the Governor’s race in Ca.  Moonbeam destroyed this state.  Please endorse like minded Trump supporter and grass roots @JoinTravisAllen .  Let’s work together.  #JoinTravisAllen #MAGA
#
# This is good work! Directly connects the Russian Facebook campaign to the #1 factor that explained support for Trump in 2016:  racial resentment.
#
# See: https://t.co/8tnIVHk5UF https://t.co/e0QfPNPAua
#
# HERE IS MY DONALD TRUMP SUPPORTER RALLY SONG BY HENRY DAVIS!!!! THANKS FOR THE LOVE AND SUPPORT!!
# @RealCandaceO @DiamondandSilk @kanyewest @THEHermanCain @realDonaldTrump @RealVinnieJames @seanhannity @KimKardashian https://t.co/7dClINO9RX
#
# @nationalpost I am very tired of hearing that President Trump is vulgar and garish or whatever but is doing a good job.  I LIKE HIM JUST THE WAY HE IS! He is the best president in m7y 60+ years on this earth,
#
# Tune in 7-8pm ET on @freespeechtv as we talk
# #metoo on the job with Diana Ramirez of @rocunited
# tackle #wagetheft
# Trump's #TipTheftRule &amp; #1fairwage
# Also, @JanzforCongress talks taking on @DevinNunes in CA's 22
#
# AT 8PM ET JOIN US FOR #OvertimeWithRick
#
# https://t.co/88fWmX90KZ
#
# @JudgeJeanine @DannyAyalon We know and President Trump’s accomplishment lists continues to get longer, so proud of him and wonderful smart people like you Judge Jeanine supporting him, #KeepAmericaGreat!
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# Trump's withdrawal from the Iran Deal not only makes the Middle East less stable and undermines our diplomatic standing in the world, but will cause gas prices to sky rocket.
#
# High gas prices hurt those in rural areas the most — i.e. Trump's base.
# https://t.co/lFmYXmAWbS
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# I add, @realDonaldTrump supports this action, this offense. He also has done nothing but trash on @SenJohnMcCain. A war Hero. As was his father. #CadetBoneSpurs refused to defend our country. And he is throwing #Hate at a Senator in his own party. #GutCheckAmerica indeed. #Resist https://t.co/l9t6XaQsyB
#
# Thank you President Trump
# Trump 2020 https://t.co/OIxtK2KKLp
#
# @EdKrassen "Kim Jong Un told me I'm the greatest leader in the world. So now we're best friends. I trust him 110%." ~ Derp Thoughts By Donny Trump #Maga #Magats https://t.co/TvI2PTWIgv
#
# HERE IS MY DONALD TRUMP SUPPORTER RALLY SONG BY HENRY DAVIS!!!! THANKS FOR THE LOVE AND SUPPORT!!
# @RealCandaceO @DiamondandSilk @kanyewest @THEHermanCain @realDonaldTrump @RealVinnieJames @seanhannity @KimKardashian https://t.co/7dClINO9RX
#
# Bandeiras americanas voando ao lado de bandeiras israelenses, banners em toda Israel, nos sinais sobre os semáforos com os dizeres; "Trump Make Israel Great". Lindo de ser ver!! https://t.co/Lf0IIXgBtA
#
# TRUTH : RED IS MY FAVORITE
# COLOR ❤🇺🇸
# PRESIDENT TRUMP IS THE  BEST PRESIDENT EVER
# MELANIA IS THE BEST  "FOREVER" FIRST LADY
# #BeBest
# #KAG
# #RedWaveRising2018
# Donald Trump Won 7.5 Million Popular Vote Landslide in Heartland | Breitbart https://t.co/PBGb1VwNCu via @BreitbartNews
#
# Brooks: 'We're in a Better Situation with North Korea' - Maybe Trump Understands Thugs Better Than People with Good SAT Scores | Breitbart https://t.co/Yh1bWRrQeI via @BreitbartNews
#
# HERE IS MY DONALD TRUMP SUPPORTER RALLY SONG BY HENRY DAVIS!!!! THANKS FOR THE LOVE AND SUPPORT!!
# @RealCandaceO @DiamondandSilk @kanyewest @THEHermanCain @realDonaldTrump @RealVinnieJames @seanhannity @KimKardashian https://t.co/7dClINO9RX
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# Some amazing Anti-Trump voices that you want to follow, RT, follow &amp; share this list!
#
# @KamalaHarris
# @tedlieu
# @TeaPainUSA
# @ProudResister
# @sahluwal
# @SenWarren
# @SethAbramson
# @RepMaxineWaters
# @SenDuckworth
# @SenSanders
# @AdamSchiffCA
# @SaysHummingbird
# @CREWcrew
#
# #TheResistance
#
# Some amazing Anti-Trump voices that you want to follow, RT, follow &amp; share this list!
#
# @KamalaHarris
# @tedlieu
# @TeaPainUSA
# @ProudResister
# @sahluwal
# @SenWarren
# @SethAbramson
# @RepMaxineWaters
# @SenDuckworth
# @SenSanders
# @AdamSchiffCA
# @SaysHummingbird
# @CREWcrew
#
# #TheResistance
#
# Wondering if anyone was keeping a list of all the damage Trump has done, so we can UNDO it when he is gone?  The answer is yes! #TheList
#
# And it continues:  https://t.co/8Rsy2pLlj7 https://t.co/NSnoKtorYT
#
# #AmericaFirst #MAGAmeetup Donald Trump #iPhone Case #TRUMPTRAIN #LOVE 4  #tpp #god #optrump https://t.co/OvoH5jBEAV
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# Trump: Day 477
# -112th Day at a Trump Golf Club
# -154th Day at a Trump Property
# -Upset Mocking Comment Leaked
# -Thanks NK 4 Collapsed Test Site
# -Lifts Sanctions 4 Putin-Linked Firm
# -Killed Greenhouse Gas Monitoring
# -Has Giuliani Walk Back Comments
# -Orders FDA 2 Only Watch FOX News https://t.co/1j3VCbMuRQ
#
# Some amazing Anti-Trump voices that you want to follow, RT, follow &amp; share this list!
#
# @KamalaHarris
# @tedlieu
# @TeaPainUSA
# @ProudResister
# @sahluwal
# @SenWarren
# @SethAbramson
# @RepMaxineWaters
# @SenDuckworth
# @SenSanders
# @AdamSchiffCA
# @SaysHummingbird
# @CREWcrew
#
# #TheResistance
#
# There's a nontrivial chance union issues become VERY interesting over next 2 yrs. Combine potentially landmark Janus decision, Trump's possible appeal to labor voters, likelihood of Dems' winning the House &amp; picking a far-left 2020 nominee...what happens?
# https://t.co/VvCIItl6W5
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/TCFMEFS0aI
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# @President1Trump @chuckschumer Interesting how liberal MSM won't resurface these comments. Hiding from the truth reality that President Trump did a great thing.
#
# P-resident
# T-rump
# S-tress
# D-isorder
#
# Thank you, Greg Gutfeld https://t.co/0cCwjkzHOu
#
# "When I voted for Trump, I never thought that he'd make every aspect of my life worse and debase our politics and debase our discourse and debase our culture. But I still believe in my heart that he's a good person and I'll be voting for him again."
#
# @calico_cato @SteveSchmidtSES @kumailn @YouTube A Moment I will never Forget., even though I voted for Obma.. Senator McCain has most times  strived for Americans to rise to their Better Angels. But Today's GOP Congressional leaders love the Darker  Angels of America more, via Trump etc.
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# My mother passed 23-years ago. She liked Donald Trump the builder, and she would’ve loved Donald Trump the President! Happy Mothers’ Day! @realDonaldTrump https://t.co/htNXMlcVs8
#
# Trump has arrived at Trump National Golf Club in Sterling, VA, according to the pool report.
#
# This is Trump's 154th day at a Trump property as president and his 112th day at a Trump golf club as president.
#
# https://t.co/s3tLQOBA1C
# 🚨PATRIOTS GIVE A SHOUT OUT TO A GREAT PATRIOT SUPPORTER THAT 💯STANDS
# UP WITH PRESIDENT TRUMP
# #MAGA
# #AmericaFirst
# #DrainTheSwamp
# #SupportOurMilitary
# #SupportTheBlue
# #ClearFlynnNow
# #TrumpsArmy
# 💯🙏🇺🇸
#
# TRUTH : RED IS MY FAVORITE
# COLOR ❤🇺🇸
# PRESIDENT TRUMP IS THE  BEST PRESIDENT EVER
# MELANIA IS THE BEST  "FOREVER" FIRST LADY
# #BeBest
# #KAG
# #RedWaveRising2018
# Donald Trump Won 7.5 Million Popular Vote Landslide in Heartland | Breitbart https://t.co/PBGb1VwNCu via @BreitbartNews
#
# @oldmansview @matt_urban1a @gatewaypundit 100% agree!  This is WHY all Independents and Republicans MUST VOTE in NOVEMBER.  If the Dems win... they will impeach Trump! Undo everything he's done!
#
# Trump's withdrawal from the Iran Deal not only makes the Middle East less stable and undermines our diplomatic standing in the world, but will cause gas prices to sky rocket.
#
# High gas prices hurt those in rural areas the most — i.e. Trump's base.
# https://t.co/lFmYXmAWbS
#
# He also believes CNN has the highest ratings in cable news! https://t.co/qnZflhwd0z
#
# Let me be clear, if Barack Obama was President these 3 wonderful gentlemen would not be on the plane with me right now.
#
# Thank you President Trump and VP Pence, they are looking forward to thanking you in person.
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# UK's May and Trump agree talks needed over Iranian sanctions https://t.co/B1LchZFYxK
#
# I think @dbongino is terrific! He is brave &amp; speaks the TRUTH loudly! #Bongino Reveals That Obama’s DOJ Had MORE Than One Mole Inside Trump’s Campaign https://t.co/MLEOPLRRnh via @truthfeednews
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# EVERYONE RETWEET THESE PICTURES BECAUSE THE LEFT WING MEDIA DOESN’T WANT YOU TO SEE THAT TRUMP IS LOVED IN ISRAEL!!!
#
# Seriously. There are Trump signs and American flags EVERYWHERE IN ISRAEL! The media doesn’t want to admit Trump is doing a great job.
#
# Cc: @realDonaldTrump https://t.co/HRFDBTzgkL
#
# Some amazing Anti-Trump voices that you want to follow, RT, follow &amp; share this list!
#
# @KamalaHarris
# @tedlieu
# @TeaPainUSA
# @ProudResister
# @sahluwal
# @SenWarren
# @SethAbramson
# @RepMaxineWaters
# @SenDuckworth
# @SenSanders
# @AdamSchiffCA
# @SaysHummingbird
# @CREWcrew
#
# #TheResistance
#
# @RyanAFournier I and the world had faith in america.  Clowns like pence and trump have crushed that on a global scale.
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# EVERYONE RETWEET THESE PICTURES BECAUSE THE LEFT WING MEDIA DOESN’T WANT YOU TO SEE THAT TRUMP IS LOVED IN ISRAEL!!!
#
# Seriously. There are Trump signs and American flags EVERYWHERE IN ISRAEL! The media doesn’t want to admit Trump is doing a great job.
#
# Cc: @realDonaldTrump https://t.co/HRFDBTzgkL
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# TRUTH : RED IS MY FAVORITE
# COLOR ❤🇺🇸
# PRESIDENT TRUMP IS THE  BEST PRESIDENT EVER
# MELANIA IS THE BEST  "FOREVER" FIRST LADY
# #BeBest
# #KAG
# #RedWaveRising2018
# Donald Trump Won 7.5 Million Popular Vote Landslide in Heartland | Breitbart https://t.co/PBGb1VwNCu via @BreitbartNews
#
# @needtruthhope @greta @CNN I wouldn't know,everytime I turn CNN on,it's Trump this and Trump that
#
# @SenJoniErnst @SenJohnMcCain I may have missed it Senator, but did u respond this way when our President stated “he’s not a war hero”?   It appears u were fine with President Trump’s response?  But this was the line?
#
# Obama rejected what makes Americans American. In the end, his goal was to 'improve' America by making it more like Europe.
#
# Trump EMBRACES what Obama &amp; his political elite class reject as 'beneath' them.
#
# He embraces what makes America unique.
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# Got to love the Trump affect.... https://t.co/EA8hb0AKMd
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# TRUTH : RED IS MY FAVORITE
# COLOR ❤🇺🇸
# PRESIDENT TRUMP IS THE  BEST PRESIDENT EVER
# MELANIA IS THE BEST  "FOREVER" FIRST LADY
# #BeBest
# #KAG
# #RedWaveRising2018
# Donald Trump Won 7.5 Million Popular Vote Landslide in Heartland | Breitbart https://t.co/PBGb1VwNCu via @BreitbartNews
#
# The Ex Resident Obama was never the leader of America because you can’t lead what you don’t love! Obama led the Progressive Globalist plot to destroy America. Thank God that on November 8 2016 Donald Trump ended his wicked agenda, and Libnuts are still in shock😂  @POTUS #MAGA
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# America’s first black billionaire says Trump economy has been good for African Americans https://t.co/WmJhIZ78PS
#
# @DeShobhaa @TOIOpinion Wow! Trump is now a role model for you!! Bas Modi nahi chahiye.......koi aur aa jaye....koi bhi!!
#
# Steve Schmidt: President Donald Trump's Unworthy To Say John McCain's Name | The 11th Hour | MSNBC https://t.co/VI5LjLLscr with @SteveSchmidtSES
#
# TRUTH : RED IS MY FAVORITE
# COLOR ❤🇺🇸
# PRESIDENT TRUMP IS THE  BEST PRESIDENT EVER
# MELANIA IS THE BEST  "FOREVER" FIRST LADY
# #BeBest
# #KAG
# #RedWaveRising2018
# Donald Trump Won 7.5 Million Popular Vote Landslide in Heartland | Breitbart https://t.co/PBGb1VwNCu via @BreitbartNews
#
# @MichaelDelauzon Thank you to all Black America’s for Trump. President Trump is the PEOPLE’S PRESIDENT. #MAGA
#
# Trump doesn't just answer the call at 3am to save Americans, unlike Obama/Clinton, he actually greets them at the airport to welcome them home from captivity.👏
#
# Thank you @POTUS Trump for exceeding our expectations of #MAGA #AmericaFirst #KAG!
#
# #WINNING👌
# https://t.co/qi1njqFSL5
#
# Steve Schmidt: President Donald Trump's Unworthy To Say John McCain's Name | The 11th Hour | MSNBC https://t.co/VI5LjLLscr with @SteveSchmidtSES
#
# @LaunaSallai @KevinKtk789 @chuckschumer @realDonaldTrump @Education4Libs @CarlaDaddesi @DaveSchreiber3 @SassyT_Joy @DonaldJTrumpJr @Jim_Jordan @SunshineLK10 I heard what he said .
# Wow Dude you are Nuts
# Totally .....😈😈😈😈😈
# I LOVE All the PRESIDENT TRUMP Winning !!!!
# I'm sure it drives you Crazy
# Schumer
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# The Ex Resident Obama was never the leader of America because you can’t lead what you don’t love! Obama led the Progressive Globalist plot to destroy America. Thank God that on November 8 2016 Donald Trump ended his wicked agenda, and Libnuts are still in shock😂  @POTUS #MAGA
#
# The Ex Resident Obama was never the leader of America because you can’t lead what you don’t love! Obama led the Progressive Globalist plot to destroy America. Thank God that on November 8 2016 Donald Trump ended his wicked agenda, and Libnuts are still in shock😂  @POTUS #MAGA
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# 💥Great Video ❤️Lov'in #RamboTrump💥
#
# 🌄#GreatAwakening 🌧️#TheRainMakers #TheStormIsUponUs🌪️
# ❤️#QAnon #ClearFlynnNow @POTUS @GenFlynn @realDonaldTrump ❤️
# 🇺🇸#MAGA #TrustThePlan #TrustInTrump #TrumpsArmy🇺🇸 https://t.co/m0EGPKBgrr
#
# To the mother who gave us @POTUS
# (may she rest in peace)
# Mary Anne MacLeod Trump
# 1912-2000
# Wherever she is- THANK YOU for  @realDonaldTrump
# Happy Mothers Day! 🌸🤗
#
# #Mothersday https://t.co/UfGVyID8BL
#
# You don't have to agree with trump but the mob can't make me not love him. We are both dragon energy. He is my brother. I love everyone. I don't agree with everything anyone does. That's what makes us individuals. And we have the right to independent thought.
#
# Awesome! Thank you, POTUS. https://t.co/yZEM9SJr1o
#
# @KatrinaPierson @omgness4real Yeeha! #KAG @realDonaldTrump I’m on Board ! NH Veterans for Trump, @codeofvets @RealErinCruz I’m deeply aligned with Gretchen and Erin! #AmericaFirst get out and Vote! SemperFi https://t.co/ak4EOWAlaE
#
# Not only was it good Trump got out of the Iran deal, it was brilliant. He's given the Middle East a choice. A Middle East with Nuclear weapons, or without. Area leaders KNOW if they have them, they WILL BE USED. Israels, Jordan, Saudis, UAE All know. NONE will allow such weapons https://t.co/IuVT17CJ2n
#
# Yes he is and he’s leagues smarter, kinder and more generous than any of you media hacks. Delete this tweet moron, you’re an embarrassment. https://t.co/dzpBZyz4AN
#
# #Good  #Donnelly announces support for Trump's CIA pick Gina Haspel https://t.co/E0EFsExqGJ
#
# i got mine from ebay, some sweat shop loving cabalist in china got my 3 bucks
#
# #FAUXDiseaseX #REX84 @realDonaldTrump #qanon #DrinkTheQlade #CLINTONCrimes #ObamaTraitor #FREEPRESS #NoVacinations https://t.co/iXdL0KmZwl
#
# While I’m on the topic, you Trump trolls LOVE to tweet me saying: “Go home if you don’t like America.”
#
# MY ancestors literally built this country in bondage while yours played card games &amp; sipped tea...&amp; my relatives have fought and died in various wars for it...Bitch, I AM HOME.
#
# Let me be clear, if Barack Obama was President these 3 wonderful gentlemen would not be on the plane with me right now.
#
# Thank you President Trump and VP Pence, they are looking forward to thanking you in person.
#
# Know anyone affected by #MKULTRA ...?   tell em have a chat with #JohnBrennan ...... #QArmy @realDonaldTrump https://t.co/s4qA5iJTl0
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# 💕💕💕💕💕💕💕💕💕💕💕.       To all the amazing moms, my friends, my patriots, and Trump warriors I want to wish you a very special day💕 💕💕💕💕Love, Gianna https://t.co/WxVtGYGlBF
#
# That's what I love about #PresidentTrump He gets things done for America! Hillary would have taken that 40 billion dollars and put it into her back account! President Trump is #MAGA 🇺🇸🇺🇸 https://t.co/DzasIqHU5B
#
# Gina Haspel apparently was involved with "destroying tapes"
#
# Sure don't vote for her for that.
#
# By all means though, vote for Hillary Clinton for President, after she destroyed states evidence, after a subpoena.
#
# Makes perfect sense. https://t.co/aW4ud4Yjdp
#
# @RodStryker @HillaryClinton @MikeTokes @charliekirk11 @Thomas1774Paine @IWillRedPillU @RubyRockstar333 @GartrellLinda @LeahR77 @RealEagleWings @DonnaWR8 @KatTheHammer1 She made America horrible yet I find comfort in knowing Trump Made America Great Again.
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# Like we believe anything he has to say! NOT!  Prove it is my answer to him! https://t.co/6CjP8AmxQm
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# My mother would have loved everything about MAGA--all of it.
#
# ~ The bold president.
# ~ The patriotic feelings.
# ~ The positive changes.
# ~ The pride in our flag.
# ~ The epic Trump rallies.
#
# Be MAGA.
# Be grateful.
# Happy Mother's Day.
#
# Some amazing Anti-Trump voices that you want to follow, RT, follow &amp; share this list!
#
# @KamalaHarris
# @tedlieu
# @TeaPainUSA
# @ProudResister
# @sahluwal
# @SenWarren
# @SethAbramson
# @RepMaxineWaters
# @SenDuckworth
# @SenSanders
# @AdamSchiffCA
# @SaysHummingbird
# @CREWcrew
#
# #TheResistance
#
# @narendramodi Thanks Trump and Kim Jong for meeting on 12th June 2018 at Singapore whole world is happy as whole world wants Peace and development only.We love this world as a one Family as all are good human beings
#
# To the mother who gave us @POTUS
# (may she rest in peace)
# Mary Anne MacLeod Trump
# 1912-2000
# Wherever she is- THANK YOU for  @realDonaldTrump
# Happy Mothers Day! 🌸🤗
#
# #Mothersday https://t.co/UfGVyID8BL
#
# Yes he is and he’s leagues smarter, kinder and more generous than any of you media hacks. Delete this tweet moron, you’re an embarrassment. https://t.co/dzpBZyz4AN
#
# @ananavarro What is happening to our country is Donald Trump is making America great again! But my question is,when will it be great does he have a time line on that us black folks need to know because while he is making it great we are dropping like flies.
#
# Gina Haspel apparently was involved with "destroying tapes"
#
# Sure don't vote for her for that.
#
# By all means though, vote for Hillary Clinton for President, after she destroyed states evidence, after a subpoena.
#
# Makes perfect sense. https://t.co/aW4ud4Yjdp
#
# Trump: Day 477
# -112th Day at a Trump Golf Club
# -154th Day at a Trump Property
# -Upset Mocking Comment Leaked
# -Thanks NK 4 Collapsed Test Site
# -Lifts Sanctions 4 Putin-Linked Firm
# -Killed Greenhouse Gas Monitoring
# -Has Giuliani Walk Back Comments
# -Orders FDA 2 Only Watch FOX News https://t.co/1j3VCbMuRQ
#
# Great content. https://t.co/1Kx1YGeVRg
#
# @maziehirono @snopes CNN #JohnKelly Kelly turn in is Star ⭐️ ⭐️ ⭐️🌟 &amp; Bar when he stood by Trump America’s Enemy of the State.
#
# Lord, Please reveal all of the Treasonous devils who have tried to overturn the election of President Trump. Bring their evil plans to naught and bring them to justice, in Jesus name Amen.
#
# Thank you President Trump for keeping your promise to recognize Jerusalem as Israel's capital and to move your embasssy here. 🇮🇱🇺🇸 https://t.co/eL5ETqYo4R
#
# @_VachelLindsay_ @GenFlynn We can only hope. It’s time to shut down that stupid investigation and let OUR GREAT PRESIDENT TRUMP do the work of the people. With all of his accomplishments imagine what OUR GREAT PRESIDENT TRUMP could’ve done without obstructionist dimwits, mueller and his team of crooks
#
# Steve Schmidt: President Donald Trump's Unworthy To Say John McCain's Name | The 11th Hour | MSNBC https://t.co/VI5LjLLscr with @SteveSchmidtSES
#
# Maxine Waters to PA Rep: 'I Resent the Remark About Making America Great Again'
#
# Rep Mike Kelly, “Stop talking about discrimination and start talking more about the nation.” “We’re coming together as a people in spite of what you say.”
#
# LOVE IT!!!!
#
# https://t.co/foo5vq1dtp
#
# Trump has arrived at Trump National Golf Club in Sterling, VA, according to the pool report.
#
# This is Trump's 154th day at a Trump property as president and his 112th day at a Trump golf club as president.
#
# Trump and His Associates Are Holding the Great American Yard Sale https://t.co/XUPixB3x0V via @Esquire
#
# @realDonaldTrump Go Trump!
#
# Trump invasion &amp; annihilation of the truth makes this task very difficult. Especially sense EVERY DAY is filled w a NEW LEVEL OF CORRUPTION. But, @JillWineBanks is right. If Trump finds any little hole in justice, he will be spending taxpayer money 4 MANY YEARS MORE--Avoiding it. https://t.co/BFOaTFaKR3
#
# Donald Trump has demonstrated that he is the most pro-Israel president in U.S. history. No other president comes close. The difference between Trump and his predecessors is that Trump accepts Israel on its own terms. #Embassy #Jerusalem
# TRUMP 🇺🇸 AMERICA FIRST #MAGA https://t.co/mtw6QJNmrF
#
# Want to know my deepest held conviction? It’s you, trump and the many crooks that surround both of you ruined, removed and in prison for conspiracy and corruption. I’ll be adding my voice to that. 🖕 https://t.co/QsEmgFB6tg
#
# We can thank Trump for that. https://t.co/tHYXp7uqh8
#
# https://t.co/vSC3V5JohG
# 🚨PATRIOTS REPOST SHOW REP.NUNES HOW WE ROCK &amp; ROLL FOR HIS BAD-ASS SUPPORTING/ STANDING
# &amp; FIGHTING TO CLEAR UP
# RUSSIA LIES AGAINST PRESIDENT TRUMP🚨
# THANK YOU 💯🙏🇺🇸
# #MAGA
# #DeepState
# #JUSTICENOW
# #TrumpsArmy
# ALWAYS &amp; FOREVER A PATRIOT💯
# 🙏🇺🇸
#
# @SiddonsDan @KatrinaPierson Trump was drawing bigger crowds than many
# big time sports teams
# Bigger than CNN
#
# Trump was on a multi state ROCK STAR TOUR
#
# AND TRUMP won the Mother of all Trophies
# @POTUS
# MOAT
# MOAT along WALL
#
# Killary still wines for just trying award.
# Lost because tried hard at being HILLARY https://t.co/VlU7slJ7Vm
#
# Retweeted Donald J. Trump (@realDonaldTrump):
#
# North Korea has announced that they will dismantle Nuclear Test Site this month, ahead of the big Summit Meeting on June 12th. Thank you, a very smart and gracious gesture!
#
# To the mother who gave us @POTUS
# (may she rest in peace)
# Mary Anne MacLeod Trump
# 1912-2000
# Wherever she is- THANK YOU for  @realDonaldTrump
# Happy Mothers Day! 🌸🤗
#
# #Mothersday https://t.co/UfGVyID8BL
#
# Young heroes trying to save future lives: James Shaw Jr. — who heroically disarmed the Waffle House gunman and saved lives — just met w/ Parkland students, including Emma Gonzalez and David Hogg. FWIW, Trump has still yet to thank James Shaw Jr https://t.co/8SF0o3vxgl #NeverAgain
#
# @cher THE DIFFERENCE IS, JOHN McCain IS A HERO.  HE IS ALSO A GENTLEMAN.  LIKE YOU, I DIDN'T ALWAYS AGREE WITH HIM, BUT I RESPECT HIM.  RESPECT IS EARNED.  TRUMP HAS DONE ZIP TO EARN RESPECT.
#
# Good thing the U.S. has such a massive infrastructure for targeting terrorism and terrorist financing. I’m sure they’ll be right on this. https://t.co/KuYARkjAMW
#
# Steve Schmidt: President Donald Trump's Unworthy To Say John McCain's Name | The 11th Hour | MSNBC https://t.co/VI5LjLLscr with @SteveSchmidtSES
#
# @ShowboatBob @ADeSenze @crawfishaka @Aadams0411 @Jayc27rwt @pigletjay @Birdle2963 @paxilbob @Iculkn57Brenda @ChristineRhyner @cdnrod @cazam_c @BozenaFox @dt7767 @lleoffled @Grtowner59Gary @tutster_2 @4nzInCali @davidyflores @BridgetKF30 @Deantheplumber1 @f_stop1079 @DEF407 Keep America Great!  Donald Trump 2020👍😎🇺🇸🇺🇸🇺🇸 https://t.co/ijVQ66EnzS

# %%
print(count_pre)
print(count_pos)
# Out:
# 5485
# 272
