# %%
SEARCH_TERM = "Karnataka"
TWEETS_COUNT = 300
TIME_LIMIT = 120



import keys
import os
import pandas as pd
import numpy as np
import tweepy
from tweepy import OAuthHandler
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline

dir_path = os.getcwd()
dir_path_data = dir_path + "/Data/"


consumer_key = keys.consumer_key
consumer_secret = keys.consumer_secret
access_token = keys.access_token
access_secret = keys.access_secret


# print(consumer_key)
# print(consumer_secret)
# print(access_token)
# print(access_secret)


print(dir_path)
print(dir_path_data)

 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)
# Out:
# /home/karthikeya/ProjectsSJSU/ML_Project
# /home/karthikeya/ProjectsSJSU/ML_Project/Data/

# %%
# Before running this code
# make a directory named Data and provide the path of the directory at INPUT_DATAPATH
# set SEARCH_TERM as what you would like to search from twitter "ex: apple"
# which would produce the list of tweets for the term "apple" 
# and also store the twitter data into the file stream_apple.json in the directory of INPUT_DATAPATH


from tweepy import Stream
from tweepy.streaming import StreamListener
import time
import string
import json
import time
import os


class MyListener(StreamListener):
    """Custom StreamListener for streaming data."""

    def __init__(self, data_dir, query, time_limit):
        query_fname = ''.join(convert_valid(one_char) for one_char in query)
        self.start_time = time.time()
        self.limit = TIME_LIMIT
        self.outfile = "%s/stream_%s.json" % (data_dir, query_fname)
        
    def on_data(self, data):
        # removes if a file already exists with same name and creates new file and writes into that
        
        if os.path.exists(self.outfile):
            if os.path.getsize(self.outfile) > 2**20 * 2**10: # 1MB
                os.remove(self.outfile)
        with open(self.outfile,'a') as f:
            try:
                f.writelines(data.strip("\n"))

                if (time.time() - self.start_time) > self.limit:
                    print('WRITE COMPLETE')
                    time.sleep(1)
                    f.close()
                    return False
                return True

            except BaseException as e:
                print("Error on_data: %s" % str(e))
                time.sleep(5)


    def on_error(self, status):
        print(status)
        return True

    
def convert_valid(one_char):
    """Convert a character into '_' if invalid.
    Arguments:
        one_char -- the char to convert
    Return:
        Character -- converted char
    """
    valid_chars = "-_.%s%s" % (string.ascii_letters, string.digits)
    if one_char in valid_chars:
        return one_char
    else:
        return '_'

# %%
twitter_stream = Stream(auth, MyListener(dir_path_data, SEARCH_TERM, TIME_LIMIT)) #calling stream function to stream in live data
twitter_stream.filter(track=[SEARCH_TERM], locations=[15.19,2.1972,75.42, 50.0040]) # filters data based on search term on storing
# Out:
# WRITE COMPLETE

# %%
from nltk.tokenize import word_tokenize, TweetTokenizer
import re
import operator 
import json
from collections import Counter
from nltk.corpus import stopwords
import string
from nltk import bigrams 
from collections import defaultdict
import nltk

com = defaultdict(lambda : defaultdict(int))
    
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via', 'RT', ':', ',', '’',
                                                   'i\'m', '…', '...', 'a', 'b', 'c'
                                                  'd','g','j','m','p','s','v','y',
                                                  'e','h','k','n','q','t','w','z',
                                                  'f','i','l','o','r','u','x', 'http', 'https',
                                                  'ó','ल','ु','்','ज','I','ब','य','द','ै','ट',
                                                   'भ','ग','प','व','ி','श','amp',
                                                   'ू','।','ध','ு','च','1','ा',]    

      

tknzr = TweetTokenizer()
num_of_tweets = 0
tweets = []
original_tweets = []
terms=''
fname = dir_path_data +'/stream_'+SEARCH_TERM+'.json'
with open(fname, 'r') as f:
    count_all = Counter()
    
    for line in f:
        num_of_tweets += 1
        tweet = json.loads(line)
        # Create a list with all the terms
        original = ''
        if 'extended_tweet' in tweet:
            terms = [term.replace('#', '') for term in tknzr.tokenize(tweet['extended_tweet']['full_text']) if term.lower() not in stop 
                                                                    and 'http' not in term
                                                                    and not term.startswith('@')]
            original = tweet.get('extended_tweet').get('full_text')
            
        elif 'retweeted_status' in tweet:
            try:
                terms = [term.replace('#', '') for term in tknzr.tokenize(tweet['retweeted_status']['extended_tweet']['full_text']) if term.lower() not in stop 
                                                                    and 'http' not in term
                                                                    and not term.startswith('@')]
                original = tweet.get('retweeted_status').get('extended_tweet').get('full_text')
            except:
                pass
        else:
            try:
                terms = [term.replace('#', '') for term in tknzr.tokenize(tweet['text']) if term.lower() not in stop 
                                                                    and 'http' not in term
                                                                    and not term.startswith('@')]
                original = tweet['text']
            except:
                pass
        
#         print(original)
        tweets.append(terms)
        original_tweets.append(original)
        terms_bigram = list(nltk.bigrams(terms))
        
#         print(terms)
#         print(terms_bigram)

        # Build co-occurrence matrix
        for i in range(len(terms)-1):            
            for j in range(i+1, len(terms)):
                w1, w2 = sorted([terms[i], terms[j]])                
                if w1 != w2:
                    com[w1][w2] += 1
    
        # Update the counter
        count_all.update(terms_bigram)
        
# Print the first 5 most frequent words
# print(count_all.most_common(10))


original_tweets = list(filter(None, original_tweets))
# every single tweet vocab put into a list
flat_list = [term for tweet in tweets for term in tweet ]
hashtags_list = [hasht for hasht in flat_list if hasht.startswith('#')]

all_terms_dist = nltk.FreqDist(flat_list)
hash_terms_dist = nltk.FreqDist(hashtags_list)


print(all_terms_dist.most_common(10))

# print(count_all.most_common())


com_max = []
# For each term, look for the most common co-occurrent terms
for t1 in com:
    t1_max_terms = sorted(com[t1].items(), key=operator.itemgetter(1), reverse=True)[:5]
    for t2, t2_count in t1_max_terms:
        com_max.append(((t1, t2), t2_count))
# Get the most frequent co-occurrences
terms_max = sorted(com_max, key=operator.itemgetter(1), reverse=True)
print(terms_max[:10])

print(num_of_tweets)


'''
Bigrams
A collocation is a sequence of words that occur together unusually often. 
Thus red wine is a collocation, whereas the wine is not. 
A characteristic of collocations is that they are resistant to substitution
with words that have similar senses; for example, maroon wine sounds definitely odd.
'''

''''''
# Out:
# [('Karnataka', 2521), ('vote', 1110), ('े', 1053), ('क', 814), ('्', 738), ('ी', 710), ('BJP', 656), ('ं', 629), ('Congress', 627), ('ि', 625)]
# [(('क', 'े'), 5904), (('े', '्'), 5492), (('ं', 'े'), 4784), (('ी', 'े'), 4782), (('ि', 'े'), 4492), (('क', '्'), 4405), (('े', 'ो'), 4116), (('क', 'ि'), 3838), (('क', 'ी'), 3826), (('ं', 'क'), 3674)]
# 2811
# ''

# %%
import math
from nltk.corpus import opinion_lexicon


# n_docs is the total n. of tweets
p_t = {}
p_t_com = defaultdict(lambda : defaultdict(int))
 
for term, n in all_terms_dist.most_common():
    p_t[term] = n / num_of_tweets
    for t2 in com[term]:
        p_t_com[term][t2] = com[term][t2] / num_of_tweets
        

positive_lex = opinion_lexicon.positive()[:]   
negative_lex = opinion_lexicon.negative()[:]
positive_vocab = [
    'good', 'nice', 'great', 'awesome', 'outstanding',
    'fantastic', 'terrific', ':)', ':-)', 'like', 'love',
    # shall we also include game-specific terms?
    # 'triumph', 'triumphal', 'triumphant', 'victory', etc.
]
positive_vocab += positive_lex
negative_vocab = [
    'bad', 'terrible', 'crap', 'useless', 'hate', ':(', ':-(',
    # 'defeat', etc.
]
negative_vocab += negative_lex

pmi = defaultdict(lambda : defaultdict(int))
for t1 in p_t:
    for t2 in com[t1]:
        denom = p_t[t1] * p_t[t2]
        pmi[t1][t2] = math.log2(p_t_com[t1][t2] / denom)
 
semantic_orientation = {}
for term, n in p_t.items():
    positive_assoc = sum(pmi[term][tx] for tx in positive_vocab)
    negative_assoc = sum(pmi[term][tx] for tx in negative_vocab)
    semantic_orientation[term] = positive_assoc - negative_assoc

semantic_sorted = sorted(semantic_orientation.items(), 
                         key=operator.itemgetter(1), 
                         reverse=True)
top_pos = semantic_sorted[:10]
top_neg = semantic_sorted[-10:]
 
print(top_pos)
print(top_neg)

# print(semantic_sorted)
# Out:
# [('Thank', 68.02297805053593), ('always', 60.24820028421342), ('State', 56.41360622996919), ('MyVoteForChange', 56.06662706448827), ('SiddaramaiahForCM', 53.02098277151471), ('KarnatakaWithCongress', 52.18070090471444), ('Many', 51.93261319645708), ('franchise', 50.49537243535347), ('5', 50.46981082949339), ('inclusive', 49.153785801864025)]
# [('Hindus', -52.028298261274394), ('corrupt', -52.21389302945358), ('CongMuslimCard', -55.02130428606792), ('Nepal', -60.077980532136024), ('Polarize', -64.83431583467353), ('anti', -69.29118357305387), ('India', -72.2950964485486), ('Congress', -82.12543640072148), ('destroyed', -90.79416255143092), ('BJP', -108.17780995722921)]

# %%
from wordcloud import WordCloud
import random

def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    wordcloud = WordCloud(background_color=color,
                      width=2500,
                      height=2000,
                      max_words=100
                     ).generate(words)
#     wordcloud.recolor(color_func = grey_color_func(word = words))
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

pos_term = [terms[0] for terms in semantic_sorted if terms[1] >= 0 
            and not terms[0].startswith('@')]

neg_term = [terms[0] for terms in semantic_sorted if terms[1] < 0 
            and not terms[0].startswith('@')]

wordcloud_draw(pos_term, 'white')
wordcloud_draw(neg_term)

# %%
count = 0
target = []
for tweet in original_tweets:
    score = 0
    pos_counter = 0
    neg_counter = 0
    for word in semantic_sorted:
        if word[0].lower() in tweet.lower() and not word[0].isdigit() and len(word[0]) >= 3:
#             print(word)
            if word[1] > 0:
                pos_counter += 1
            if word[1] < 0:
                neg_counter += 1
        
            score += word[1]
    if(pos_counter > neg_counter or score > 0):
        count += 1
        sentiment = 'Positive'
    else:
        sentiment = 'Negative'
    target.append(sentiment)

# %%
print(count)
print(len(original_tweets))
print(len(target))
# Out:
# 1751
# 2177
# 2177

# %%
# We create a pandas dataframe as follows:
pd.set_option('display.max_colwidth', -1) # Setting this so we can see the full content of cells
df = pd.DataFrame(data=[tweet for tweet in original_tweets], columns=['text'])
df['sentiment']  = np.array([sentiment for sentiment in target])

# %%
import re
from textblob import TextBlob


def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analyze_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
#     print(clean_tweet(tweet))
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 'Positive'
#     elif ( analysis.sentiment.polarity == 0):
#         return 'Neutral'
    else:
        return 'Negative'

def analyze_subject(tweet):
    '''
    Utility function to classify the subjectivity of a tweet
    using textblob.
    '''
#     print(clean_tweet(tweet))
    analysis = TextBlob(clean_tweet(tweet))
    return analysis.sentiment.subjectivity
#     if analysis.sentiment.subjectivity > 0.5:
#         return 'Subjective'
#     else:
#         return 'Not Subjective'



# We create a column with the result of the analysis:
df['SA'] = np.array([ analyze_sentiment(tweet) for tweet in df['text'] ])
df['Subjective'] = np.array([ analyze_subject(tweet) for tweet in df['text'] ])

# We display the updated dataframe with the new column:
display(df[['text', 'SA', 'Subjective']].head())

pos_tweets_SA = [ tweet for index, tweet in enumerate(df['text']) if df['SA'][index] == 'Positive']
neg_tweets_SA = [ tweet for index, tweet in enumerate(df['text']) if df['SA'][index] == 'Negative']
# neu_tweets = [ tweet for index, tweet in enumerate(df['text']) if df['SA'][index] == 'Neutral']

pos_tweets = [ tweet for index, tweet in enumerate(df['text']) if df['sentiment'][index] == 'Positive']
neg_tweets = [ tweet for index, tweet in enumerate(df['text']) if df['sentiment'][index] == 'Negative']

print("Percentage of positive tweets SA: {}%".format(len(pos_tweets_SA)*100/len(df['text'])))
print("Percentage de negative tweets SA: {}%".format(len(neg_tweets_SA)*100/len(df['text'])))

print("Percentage of positive tweets Sentiment: {}%".format(len(pos_tweets)*100/len(df['text'])))
print("Percentage de negative tweets Sentiment: {}%".format(len(neg_tweets)*100/len(df['text'])))
# Out:
#                                                                                                                                                                                                                                                               text  \
# 0  Its Our duty to protect Karnataka from the CONgress Buffaloes who murdered Kannada.\n\nಕನ್ನಡವನ್ನು ಕೊಂದ ಕಾಂಗ್ರೆಸ್ ಎಮ್ಮೆಗಳಿಂದ ಕರ್ನಾಟಕವನ್ನು ರಕ್ಷಿಸುವ ಜವಾಬ್ದಾರಿ ಇಂದು ಕನ್ನಡಿಗರ ಮೇಲಿದೆ.\n\n#ಸರ್ಕಾರಬದಲಿಸಿಬಿಜೆಪಿಗೆಲ್ಲಿಸಿ\n\n#KarnatakaVotes4BJP https://t.co/kldObBQPEE
def load_pickle(file_name):
    with open(file_name + '.pickle', 'rb') as file:
        classifier = pickle.load(file)
    return classifier

# %%
classifier = load_pickle('vec_clf')

# %%
# classifier.score(data_test, targets_test)
# predicted = classifier.predict(vectorized_data)
print(classifier)
def sentiment2target(sentiment):
    return {
        'Negative': 0,
        'Positive' : 1
    }[sentiment]

# Convert Classification into integer for speed and space efficiency reasons
targets_SA = df.SA.apply(sentiment2target)
targets_sentiment = df.sentiment.apply(sentiment2target)
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#        ...',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
predicted = classifier.predict(df.text)

# %%
np.mean(predicted == targets_SA)
# Out:
# 0.5475424896646761

# %%
np.mean(predicted == targets_sentiment)
# Out:
# 0.23977951309141018

# %%
count_pre = 0
count_pos = 0
for pre in predicted:
    if pre == 1:
        count_pos += 1
        print(df.text[count_pre])
        print("")
    count_pre += 1
# Out:
# Good Morning Karnataka!!!
# Rise and take the RIGHT decision!
# Vote Wisely!
# Vote For Communal Harmony!
# Vote For Development!
# Vote For Safety For Women!
# Vote For Humanity!
# Vote For Good vs Bad!
# Vote For Truth vs Lies!
# Vote for Congress!
#
# #KarnatakaVotesForCongress https://t.co/m0PWpSPwZe
#
# @AdiGuru_Ji @iamWali10 @Spoof_Junkie @Saurabh_MLAgk AAP to get 105% vote share and all the seats of Karnataka as well as Tamilnadu assembly.
#
# *Extra vote share for good humour*
#
# This election will decide the future of Karnataka. Lets take a pledge to throw the Corrupt Congress Govt. headed by Siddaramaiah permanently and Vote for Change, Vote for Good Governance  #PressLotus
#
# Kindly everyone of Karnataka go and to vote in large numbers today.  All young voters must vote and enrich this festival of democracy with their participation.#PressLotus
#
# #KarnatakaElections2018 MY VOTE IS FIRST IN MY BOOTH, I VOTED FOR JAGRUTHA KARNATAKA. https://t.co/yyDiQMP90A
#
# Make Karnataka great again ...bring back the glory of Bangalore..vote for BJP vote for change
#
# Good Morning Karnataka!!!
# Rise and take the RIGHT decision!
# Vote Wisely!
# Vote For Communal Harmony!
# Vote For Development!
# Vote For Safety For Women!
# Vote For Humanity!
# Vote For Good vs Bad!
# Vote For Truth vs Lies!
# Vote for Congress!
#
# #KarnatakaVotesForCongress https://t.co/m0PWpSPwZe
#
# It's a clear fight in Karnataka. Clean Politics vs Dirty Politics. Mafia vs People. With the BJP fielding the corrupt Reddy gang, we are trying a novel approach to fund our candidate. Support our candidate by making a  contribution.
# #CleanPoliticswithINC
#
# https://t.co/D6zkzjxAgH
#
# @RahulGandhi Rahul Gandhi ji, Keep ur eyes on Karnataka Voters. Voters must be convinced that promises u did to them will be fulfilled to their maximum satisfaction. All the best to u and ur team players.
#
# It's a clear fight in Karnataka. Clean Politics vs Dirty Politics. Mafia vs People. With the BJP fielding the corrupt Reddy gang, we are trying a novel approach to fund our candidate. Support our candidate by making a  contribution.
# #CleanPoliticswithINC
#
# https://t.co/D6zkzjxAgH
#
#
# It's a clear fight in Karnataka. Clean Politics vs Dirty Politics. Mafia vs People. With the BJP fielding the corrupt Reddy gang, we are trying a novel approach to fund our candidate. Support our candidate by making a  contribution.
# #CleanPoliticswithINC
#
# https://t.co/D6zkzjxAgH
#
# People of Karnataka, good luck voting today!
#
# And for everyone else, today is a good day to go to a petrol pump and fill up your car. There are very high chances that petrol prices will drastically increase from tomorrow onwards because elections are now over.
#
# #FillBeforeYouVote
#
# People of Karnataka, good luck voting today!
#
# And for everyone else, today is a good day to go to a petrol pump and fill up your car. There are very high chances that petrol prices will drastically increase from tomorrow onwards because elections are now over.
#
# #FillBeforeYouVote
#
# To all the people of Karnataka,
#
# Vote for a stable Govt &amp; good governance. Vote for progress, peace, love &amp; harmony. Vote for pluralism.
#
# Reject politics of hate, bigotry, communalism, corruption, divisiveness.
#
# Vote for Karnataka. Vote Congress! #KarnatakaVotesForCongress
#
# Good Morning 💐🙏🙏🙏🚩🚩🙏 Jai Shree Ram 🙏 abb Karnataka to main ja nahi Sakti yahi pe kehti hun sab vote karo....siddha pidhha k ghamand Todo piddio Ko chup karao aur vote dekar Kamal khilao 🙏
#
# Hello Karnataka, please get out and vote. And while you're at it, please get out and vote Congress. And if you're a Congress supporter, please help to get out the vote. Thank you so much.
# #KarnatakaVotesForCongress https://t.co/FiX0Awl9Uz
#
# I appeal to all the people of Karnataka especially Telugu brethren to come out in large numbers &amp; vote for development, prosperity &amp; good governance. It is this day that decides the future course of next 5 yrs.
# #SarkaraBadalisiBJPGellisi
# #Vote4ChangeVote4BJP
# #KarnatakaVotes4BJP https://t.co/RV5K9yNl71
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# Yrswe have to reject the goons, great to see #KarnatakaDefeatsBJP KARNATAKA DEFEATS BJP https://t.co/akiLZlyTgv
#
# Thisi is always best to see this oen #KarnatakaDefeatsBJP KARNATAKA DEFEATS BJP and Congress will win
#
# Just pressed laptop power button and message displayed on Screen "Thank you for voting for BJP in Karnataka"
# Scarry things are happening in our country https://t.co/CAw0Hq53Xw
#
# Dear Kannadigas,
#
# Today is the day which will create a Political history In karnataka.
# Lets Come out &amp; Vote
# Vote For Change
# Vote For Devlopment
# Vote For Education
# Vote For Security
# In short Vote For our Better Future.
# Please wake up and vote wisely.
#
# #KarnatakaVotes4BJP https://t.co/jWfaQbHLpK
#
# Time to come ahead her efor best one now #KarnatakaDefeatsBJP KARNATAKA DEFEATS BJP and Congress will win
#
# Come on Karnataka. Go out there and vote in big numbers. And Bangalore, please set an example or at least match the turnout of the rest of the State. Target at least 70% plus polling.
#
# Go for the best here with #KarnatakaDefeatsBJP KARNATAKA DEFEATS BJP and Congress will win
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
#
# Vote for Karnataka. Vote Congress! #KarnatakaVotesForCongress
#
# #KarnatakaVoting Despite overnight rains and a relatively cool weather in Bengaluru, the voters in the city showed more enthusiasm today.
# https://t.co/nOupJZEyP2
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# Good Morning Karnataka!!!
# Rise and take the RIGHT decision!
# Vote Wisely!
# Vote For Communal Harmony!
# Vote For Development!
# Vote For Safety For Women!
# Vote For Humanity!
# Vote For Good vs Bad!
# Vote For Truth vs Lies!
# Vote for Congress!
#
# #KarnatakaVotesForCongress https://t.co/m0PWpSPwZe
#
# #Vote4ChangeVote4BJP
# Must Watch
# what Karnataka people want
# @narendramodi ji at Center
# @BSYBJP ji in State
# Law &amp; Order in state
# Good infrastructure
# Development for All
# Ache din Ayenge
# @CTRavi_BJP @mepratap https://t.co/5h0rG6y1jG
#
# #KarnatakaVotesForCongress
# *Right Now*
#
# On this momentous day, Karnataka shows its support to Congress by voting for the party that has provided the state with 5 years of strong and stable governance.
#
# #KarnatakaVotesForCongress
# *Right Now*
#
# #KarnatakaVoting Despite overnight rains and a relatively cool weather in Bengaluru, the voters in the city showed more enthusiasm today.
# https://t.co/5ydeTkKFZN
#
# #KarnatakaVoting Despite overnight rains and a relatively cool weather in Bengaluru, the voters in the city showed more enthusiasm today.
# https://t.co/5ydeTkKFZN
#
# #KarnatakaVoting Despite overnight rains and a relatively cool weather in Bengaluru, the voters in the city showed more enthusiasm today.
# https://t.co/5ydeTkKFZN
#
# To all the people of Karnataka,
#
# Vote for a stable Govt &amp; good governance. Vote for progress, peace, love &amp; harmony. Vote for pluralism.
#
# Reject politics of hate, bigotry, communalism, corruption, divisiveness.
#
# Vote for Karnataka. Vote Congress! #KarnatakaVotesForCongress
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# As Karnataka votes today, urging people in Karnataka to turnout in large numbers &amp; cast their vote. Vote for progressive politics and development.
#
# #KarnatakaVotes4BJP
#
# If You are in Karnataka and Eligible to Vote , I urge you to Vote and Inspire many more!!!
#
# As @NkBlr pointed out, I think we need hourly updates for VFS awards.
#
# Today's award for the best adapted screenplay goes to Ashok Gehlot.
#
# #VerifiedForStupidity https://t.co/GZdOxNWGqF
#
# Karnataka will vote for BJP government to bring in Modi-led development :)
#
# #KarnatakaVotes4BJP
# #KarnakataElection2018
#
# https://t.co/AqsWItjXdB
#
# It's really great to see #KarnatakaDefeatsBJP KARNATAKA DEFEATS BJP because of thier previous sins https://t.co/ul0lYbOdK5
#
# They will vote Modi ji whom they show so very much love and affection.
# #Vote4ChangeVote4BJP
#
# As @NkBlr pointed out, I think we need hourly updates for VFS awards.
#
# Today's award for the best adapted screenplay goes to Ashok Gehlot.
#
# #VerifiedForStupidity https://t.co/GZdOxNWGqF
#
# People of Karnataka, good luck voting today!
#
# And for everyone else, today is a good day to go to a petrol pump and fill up your car. There are very high chances that petrol prices will drastically increase from tomorrow onwards because elections are now over.
#
# #FillBeforeYouVote
#
# It's really great to see #KarnatakaDefeatsBJP KARNATAKA DEFEATS BJP because of thier previous sins https://t.co/nUahUKPPuW
#
# People of Karnataka, good luck voting today!
#
# And for everyone else, today is a good day to go to a petrol pump and fill up your car. There are very high chances that petrol prices will drastically increase from tomorrow onwards because elections are now over.
#
# #FillBeforeYouVote
#
# @INCKarnataka @INCIndia @siddaramaiah @RahulGandhi @DrParameshwara He needs no introduction.The most loved,the most popular &amp; charismatic leader,The SULTAN OF #karnataka @siddaramaiah Who turned this state into the best business destination.#SiddaramaiahForCM #KarnatakaVotesForCongress #KarnatakaWithCongress
# https://t.co/uEjpYNPEOt
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# #FlashAlert The big electoral shift is now happening in Karnataka? CM @siddaramaiah now has a perilous 1 point lead in Badami, till last week he enjoyed 8% lead here https://t.co/pvClDTTKSu
# Remember, he is already trailing in Chamundeshwari https://t.co/9kiYPsSi0e
#
# Hello,  Karnataka...
# Rise and take the RIGHT decision.
# •Vote Wisely,
# •Vote For Communal Harmony,
# •Vote For Development,
# •Vote For Safety For Women,
# •Vote For Good vs Bad,
# •Vote For Truth vs Lies,
# •Vote for Congress ✋🏻.
#
# #KarnatakaVotesForCongress
#
# Karnataka is already the best developed state and will continue to be so under the dynamic leadership of Shri. @siddaramaiah ji. Your vote matters. So vote wisely. Love is always stronger than Hate. Remember that. Good Luck.!!!
# #KarnatakaVotesForCongress
#
# MEP is the future of the Karnataka
# No doubt best party to vote for #MyVote4MEP
#
# As Karnataka votes today, urging people in Karnataka to turnout in large numbers &amp; cast their vote. Vote for progressive politics and development.
#
# #KarnatakaVotes4BJP
#
# I stayed in Bangalore near about 8 Yrs nd very well aware what is the biggest challenge of Karnataka. My best wishes to all of u on voting day.Your vote will decide the government u want, but do remember Only @BJP4India can bring Change we want. #Vote4ChangeVote4BJP https://t.co/u1yBnBoRhw
#
# People of Karnataka, good luck voting today!
#
# And everyone else in India, today is a good day to go to petrol pump and fill up your car. It is highly expected that petrol prices will drastically increase from tomorrow onwards because elections are now over.
#
# Karnataka is choosing development over Jumla.
# Truth on lies.
# Love on hate.
# Unity on division.
# Honest on Corrupts.
# Peace on destruction.
# Sincerity over Nautanki.
#
# #KarnatakaVotesForCongress https://t.co/Tbm4JWhxDf
#
# @TajinderBagga Yes I agree with you Karnataka will vote for real development . Kannadi's are far more intelligent than we the north Indians. 😀
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# Karnataka is choosing development over Jumla.
# Truth on lies.
# Love on hate.
# Unity on division.
# Honest on Corrupts.
# Peace on destruction.
# Sincerity over Nautanki.
#
# #KarnatakaVotesForCongress https://t.co/Tbm4JWhxDf
#
# Thank you for the pleasant surprise @PiyushGoyal ! Wonderful special train for Karnataka Elections from Yeshwantpur to Belgavi.
# The station is so clean, I see a lot more dustbins inside the train and in the station as well.
# #DevelopmentSpeaks #SwachchBharat #ShresthaBharat https://t.co/uL2fqeUhaV
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# I have caste my Vote!
# Not for CASTE-POLITICS
# But for Development of “New Karnataka”
#
# I am A PROUD HINDU, a PROUD LINGAYAT ✨😇
# I hv put my conscious VOTE FOR BJP ✌️for our @narendramodi
#
# #Vote4ChangeVote4BJP
#  #KarnatakaVoting
# #AssemblyElection #SarkaraBadalisiBJPGellisi https://t.co/8xk782QAhf
#
# My son Dr Yatindra Siddaramaiah &amp; I have cast our vote in Varuna today.
#
# Karnataka voters as always will display political maturity &amp; will begin a change that our country needs the most.
#
# Please go out &amp; vote for an inclusive &amp; peaceful Karnataka.
#
# #KarnatakaVoting https://t.co/YHLqASbVmP
#
# Karnataka wake up.. Change your government, change your future...
#
# Vote 4 development , Vote 4 nation
# Vote 4 BJP..
#  #KarnatakaVotes4BJP https://t.co/ml14pXFsMZ
#
# Go out and vote in large numbers Karnataka.  Break all previous turnout records! 👊#KarnatakaVoting
# #KarnatakaPolling
# #KarnatakaElections2018
# #BattleForKarnataka
#
# Who is good for Karnataka Politics? Public gives Dhaba journo @sardesairajdeep answer- MODI, BJP 👏👏#Vote4ChangeVote4BJP
# #KarnatakaPolling https://t.co/PETV7SLWWl
#
# Cast my vote in Kanakapura constituency along with my family members. Happy to see people turning out in large numbers.
#
# I appeal again to all citizens to vote for a progressive &amp; Inclusive Karnataka. Let's make history together. #KarnatakaElection https://t.co/L0gZc97ayF
#
# Thank you Karnataka!
#
# Gratitude to the people of Karnataka for voting in large numbers today. @BJP4Karnataka is headed towards a landslide victory with all your blessings and support!
#
# #KarnatakaVotes4BJP
# #KarnatakaElections2018
#
# Thank you Karnataka!
#
# Gratitude to the people of Karnataka for voting in large numbers today. @BJP4Karnataka is headed towards a landslide victory with all your blessings and support!
#
# #KarnatakaVotes4BJP
# #KarnatakaElections2018

# %%
print(count_pre)
print(count_pos)
print("Percentage of Positive tweets: ", str((count_pos/count_pre)*100), "%")
print("Percentage of Negative tweets: ", str(((count_pre-count_pos)/count_pre)*100), "%")
# Out:
# 2177
# 110
# Percentage of Positive tweets:  5.052824988516306 %
# Percentage of Negative tweets:  94.9471750114837 %
